# %%
# Import dependencies
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util
import os
import pandas as pd
from pprint import pprint
import billboard
import matplotlib.pyplot as plt
import statistics
from scipy import stats
from config import client_id, client_secret, redirect_uri, username
import numpy as np
from sklearn import preprocessing

# %%
# Boiler plate code to authenticate Spotify API
os.environ['SPOTIPY_CLIENT_ID']= client_id
os.environ['SPOTIPY_CLIENT_SECRET']= client_secret
os.environ['SPOTIPY_REDIRECT_URI']= redirect_uri

client_credentials_manager = SpotifyClientCredentials()
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
scope = 'user-library-read playlist-read-private'
token = util.prompt_for_user_token(username, scope)
if token:
   sp = spotipy.Spotify(auth=token)
else:
   print("Can't get token for", username)

# %%
hot_chart = billboard.ChartData('hot-100')
country_chart = billboard.ChartData('country-songs')
rap_chart = billboard.ChartData('rap-songs')
pop_chart = billboard.ChartData('pop-songs')

# %%
# Define function to retrieve data from Billboard charts
def ChartMusic(chart):
    artists = []
    songs = []
    weeks=[]
    for song in chart:
        artists.append(song.artist)
        songs.append(song.title)
        weeks.append(song.weeks)
        
    return(artists, songs)

# %%
# Get Data from Billboard charts
hot_artist = []
hot_songs =  []
country_artists=[]
country_songs=[]
rap_artists=[]
rap_songs=[]
pop_artists = []
pop_songs = []

hot_artist, hot_songs = ChartMusic(hot_chart)
country_artists, country_songs = ChartMusic(country_chart)
rap_artists, rap_songs = ChartMusic(rap_chart)
pop_artists, pop_songs = ChartMusic(pop_chart)

# %%
# Verify length of list
print(len(hot_songs))
# Out:
# 100

# %%
# Define function to get spotify track info from song names on the list
def get_track_info(song_list):
    '''Takes a list of song names and searches spotify for their track information. Returns a DF containing this info'''
    track_info = []
    for song_name in song_list:
        info=sp.search(q=song_name, type='track')['tracks']['items'][0]
        track_info.append(info)
        
    # make a pandas df of the responses
    df = pd.DataFrame(track_info)
    
    # Drop Columns that make the datat look messy
    columns_to_drop = ['album', 'artists', 'available_markets', 'external_ids', 'external_urls', 'href', 'uri', 'type', 'duration_ms', 'disc_number']
    df_clean = df.drop(columns=columns_to_drop)
    
    # pprint(info)
    return(df_clean)

# %%
# Define a function to get the high-level feature analysis from spotify for each track id
def feature_analyzer(track_ids):
    '''Takes a list of track ids and calls the Spotify API for audio feature analysis. Returns a DF of the analyis'''
    features_list = []

    for track_id in track_ids:
        features = sp.audio_features(tracks=track_id)[0]
        features_list.append(features)
    
    df = pd.DataFrame(features_list)
    
    # Drop Columns that make the datat look messy
    columns_to_drop = ['analysis_url', 'track_href', 'type', 'uri']
    df_clean = df.drop(columns=columns_to_drop)

    return(df_clean)

# %%
# Get hot-100 billbaord data, print df to verify
hot_track_df = get_track_info(hot_songs)
hot_track_df.head()
# Out:
#    explicit                      id  is_local                            name  \
# 0      True  6FRLCMO5TUHTexlWo8ym1W     False  Girls Like You (feat. Cardi B)
# 1      True  0s3nnoMeVWz3989MkNQiRf     False                    Lucid Dreams
# 2      True  7dt6x5M1jzdTEt8oCbisTK     False                      Better Now
# 3      True  2G7V7zsVDxg1yRsu7Ew9RJ     False                  In My Feelings
# 4      True  1jo3TwNGCXfNdB5uba3ZVv     False                        Killshot
#
#    popularity preview_url  track_number
# 0          94        None             1
# 1          98        None             3
# 2          96        None             9
# 3         100        None             9
# 4          90        None             1

# %%
# Get hot-100 song analysis
hot_features = feature_analyzer(hot_track_df['id'])
hot_features.head()
# Out:
#    acousticness  danceability  duration_ms  energy                      id  \
# 0        0.5680         0.851       235545   0.541  6FRLCMO5TUHTexlWo8ym1W
# 1        0.3490         0.511       239836   0.566  0s3nnoMeVWz3989MkNQiRf
# 2        0.3540         0.680       231267   0.563  7dt6x5M1jzdTEt8oCbisTK
# 3        0.0589         0.835       217925   0.626  2G7V7zsVDxg1yRsu7Ew9RJ
# 4        0.0989         0.892       253580   0.651  1jo3TwNGCXfNdB5uba3ZVv
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0           0.00000    0     0.130    -6.825     1       0.0505  124.959
# 1           0.00000    6     0.340    -7.230     0       0.2000   83.903
# 2           0.00000   10     0.136    -5.843     1       0.0454  145.028
# 3           0.00006    1     0.396    -5.833     1       0.1250   91.030
# 4           0.00000    0     0.371    -8.645     0       0.3780  105.814
#
#    time_signature  valence
# 0               4    0.448
# 1               4    0.218
# 2               4    0.374
# 3               4    0.350
# 4               4    0.599

# %%
# Merge data frames together on id
hot_df = pd.merge(hot_track_df, hot_features, how='outer', on='id')
hot_df['genre']='hot-100'
hot_df.head()
# Out:
#    explicit                      id  is_local                            name  \
# 0      True  6FRLCMO5TUHTexlWo8ym1W     False  Girls Like You (feat. Cardi B)
# 1      True  0s3nnoMeVWz3989MkNQiRf     False                    Lucid Dreams
# 2      True  7dt6x5M1jzdTEt8oCbisTK     False                      Better Now
# 3      True  7dt6x5M1jzdTEt8oCbisTK     False                      Better Now
# 4      True  7dt6x5M1jzdTEt8oCbisTK     False                      Better Now
#
#    popularity preview_url  track_number  acousticness  danceability  \
# 0          94        None             1         0.568         0.851
# 1          98        None             3         0.349         0.511
# 2          96        None             9         0.354         0.680
# 3          96        None             9         0.354         0.680
# 4          96        None             9         0.354         0.680
#
#    duration_ms   ...     instrumentalness  key  liveness  loudness  mode  \
# 0       235545   ...                  0.0    0     0.130    -6.825     1
# 1       239836   ...                  0.0    6     0.340    -7.230     0
# 2       231267   ...                  0.0   10     0.136    -5.843     1
# 3       231267   ...                  0.0   10     0.136    -5.843     1
# 4       231267   ...                  0.0   10     0.136    -5.843     1
#
#    speechiness    tempo  time_signature  valence    genre
# 0       0.0505  124.959               4    0.448  hot-100
# 1       0.2000   83.903               4    0.218  hot-100
# 2       0.0454  145.028               4    0.374  hot-100
# 3       0.0454  145.028               4    0.374  hot-100
# 4       0.0454  145.028               4    0.374  hot-100
#
# [5 rows x 21 columns]

# %%
# Track info for Country
country_track_df = get_track_info(country_songs)
country_track_df.head()
# Out:
#    explicit                      id  is_local  \
# 0     False  7iDa6hUg2VgEL1o1HjmfBn     False
# 1     False  1co0puPTYvqAdUEjFOjne9     False
# 2     False  7Il2yWQmsqKgSkLQvHTPUI     False
# 3     False  698eQRku24PIYPQPHItKlA     False
# 4     False  1HXy5I3HTWq8OvxCn0z7G7     False
#
#                                        name  popularity  \
# 0  Meant to Be (feat. Florida Georgia Line)          88
# 1                                    Simple          82
# 2                                   Tequila          80
# 3                    She Got the Best of Me          79
# 4                                    Heaven          82
#
#                                          preview_url  track_number
# 0  https://p.scdn.co/mp3-preview/8965aca26c5af239...             6
# 1                                               None             1
# 2  https://p.scdn.co/mp3-preview/87979ad13f81aa74...             1
# 3  https://p.scdn.co/mp3-preview/2c94e74aa5122c6e...            17
# 4  https://p.scdn.co/mp3-preview/6bdb8646df7ad70b...            15

# %%
# Audio analyis for country
country_features = feature_analyzer(country_track_df['id'])
country_features.head()
# Out:
#    acousticness  danceability  duration_ms  energy                      id  \
# 0        0.0470         0.643       163870   0.783  7iDa6hUg2VgEL1o1HjmfBn
# 1        0.0848         0.375       185200   0.889  1co0puPTYvqAdUEjFOjne9
# 2        0.0292         0.474       195987   0.594  7Il2yWQmsqKgSkLQvHTPUI
# 3        0.0292         0.533       183160   0.907  698eQRku24PIYPQPHItKlA
# 4        0.2630         0.677       179507   0.556  1HXy5I3HTWq8OvxCn0z7G7
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0               0.0   10     0.083    -6.458     1       0.0856  154.084
# 1               0.0    3     0.136    -3.704     1       0.0991  199.669
# 2               0.0   11     0.133    -5.756     1       0.0289   86.131
# 3               0.0   11     0.386    -3.793     1       0.0406  150.990
# 4               0.0    9     0.105    -6.544     1       0.0306   80.009
#
#    time_signature  valence
# 0               4    0.579
# 1               4    0.881
# 2               4    0.503
# 3               4    0.700
# 4               4    0.521

# %%
# Merge Country
country_df = pd.merge(country_track_df, country_features, how='outer', on='id')
country_df['genre']='country'
country_df.head()
# Out:
#    explicit                      id  is_local  \
# 0     False  7iDa6hUg2VgEL1o1HjmfBn     False
# 1     False  1co0puPTYvqAdUEjFOjne9     False
# 2     False  7Il2yWQmsqKgSkLQvHTPUI     False
# 3     False  698eQRku24PIYPQPHItKlA     False
# 4     False  1HXy5I3HTWq8OvxCn0z7G7     False
#
#                                        name  popularity  \
# 0  Meant to Be (feat. Florida Georgia Line)          88
# 1                                    Simple          82
# 2                                   Tequila          80
# 3                    She Got the Best of Me          79
# 4                                    Heaven          82
#
#                                          preview_url  track_number  \
# 0  https://p.scdn.co/mp3-preview/8965aca26c5af239...             6
# 1                                               None             1
# 2  https://p.scdn.co/mp3-preview/87979ad13f81aa74...             1
# 3  https://p.scdn.co/mp3-preview/2c94e74aa5122c6e...            17
# 4  https://p.scdn.co/mp3-preview/6bdb8646df7ad70b...            15
#
#    acousticness  danceability  duration_ms   ...     instrumentalness  key  \
# 0        0.0470         0.643       163870   ...                  0.0   10
# 1        0.0848         0.375       185200   ...                  0.0    3
# 2        0.0292         0.474       195987   ...                  0.0   11
# 3        0.0292         0.533       183160   ...                  0.0   11
# 4        0.2630         0.677       179507   ...                  0.0    9
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0     0.083    -6.458     1       0.0856  154.084               4    0.579
# 1     0.136    -3.704     1       0.0991  199.669               4    0.881
# 2     0.133    -5.756     1       0.0289   86.131               4    0.503
# 3     0.386    -3.793     1       0.0406  150.990               4    0.700
# 4     0.105    -6.544     1       0.0306   80.009               4    0.521
#
#      genre
# 0  country
# 1  country
# 2  country
# 3  country
# 4  country
#
# [5 rows x 21 columns]

# %%
# Track info for Rap
rap_tracks_df = get_track_info(rap_songs)
rap_tracks_df.head()
# Out:
#    explicit                      id  is_local            name  popularity  \
# 0      True  0s3nnoMeVWz3989MkNQiRf     False    Lucid Dreams          98
# 1      True  7dt6x5M1jzdTEt8oCbisTK     False      Better Now          96
# 2      True  2G7V7zsVDxg1yRsu7Ew9RJ     False  In My Feelings         100
# 3      True  1jo3TwNGCXfNdB5uba3ZVv     False        Killshot          90
# 4      True  2xLMifQCjDGFmkHkpNLD9h     False      SICKO MODE          98
#
#                                          preview_url  track_number
# 0                                               None             3
# 1                                               None             9
# 2                                               None             9
# 3                                               None             1
# 4  https://p.scdn.co/mp3-preview/1c3c01c64477b356...             3

# %%
# Audio analysis fo rap
rap_features = feature_analyzer(rap_tracks_df['id'])
rap_features.head()
# Out:
#    acousticness  danceability  duration_ms  energy                      id  \
# 0       0.34900         0.511       239836   0.566  0s3nnoMeVWz3989MkNQiRf
# 1       0.35400         0.680       231267   0.563  7dt6x5M1jzdTEt8oCbisTK
# 2       0.05890         0.835       217925   0.626  2G7V7zsVDxg1yRsu7Ew9RJ
# 3       0.09890         0.892       253580   0.651  1jo3TwNGCXfNdB5uba3ZVv
# 4       0.00513         0.834       312820   0.730  2xLMifQCjDGFmkHkpNLD9h
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0           0.00000    6     0.340    -7.230     0       0.2000   83.903
# 1           0.00000   10     0.136    -5.843     1       0.0454  145.028
# 2           0.00006    1     0.396    -5.833     1       0.1250   91.030
# 3           0.00000    0     0.371    -8.645     0       0.3780  105.814
# 4           0.00000    8     0.124    -3.714     1       0.2220  155.008
#
#    time_signature  valence
# 0               4    0.218
# 1               4    0.374
# 2               4    0.350
# 3               4    0.599
# 4               4    0.446

# %%
# Merge rap
rap_df = pd.merge(rap_tracks_df, rap_features, how='outer', on='id')
rap_df['genre']='rap'
rap_df.head()
# Out:
#    explicit                      id  is_local            name  popularity  \
# 0      True  0s3nnoMeVWz3989MkNQiRf     False    Lucid Dreams          98
# 1      True  7dt6x5M1jzdTEt8oCbisTK     False      Better Now          96
# 2      True  2G7V7zsVDxg1yRsu7Ew9RJ     False  In My Feelings         100
# 3      True  1jo3TwNGCXfNdB5uba3ZVv     False        Killshot          90
# 4      True  2xLMifQCjDGFmkHkpNLD9h     False      SICKO MODE          98
#
#                                          preview_url  track_number  \
# 0                                               None             3
# 1                                               None             9
# 2                                               None             9
# 3                                               None             1
# 4  https://p.scdn.co/mp3-preview/1c3c01c64477b356...             3
#
#    acousticness  danceability  duration_ms  ...    instrumentalness  key  \
# 0       0.34900         0.511       239836  ...             0.00000    6
# 1       0.35400         0.680       231267  ...             0.00000   10
# 2       0.05890         0.835       217925  ...             0.00006    1
# 3       0.09890         0.892       253580  ...             0.00000    0
# 4       0.00513         0.834       312820  ...             0.00000    8
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0     0.340    -7.230     0       0.2000   83.903               4    0.218
# 1     0.136    -5.843     1       0.0454  145.028               4    0.374
# 2     0.396    -5.833     1       0.1250   91.030               4    0.350
# 3     0.371    -8.645     0       0.3780  105.814               4    0.599
# 4     0.124    -3.714     1       0.2220  155.008               4    0.446
#
#    genre
# 0    rap
# 1    rap
# 2    rap
# 3    rap
# 4    rap
#
# [5 rows x 21 columns]

# %%
# Get pop spotify analysis. Use this for later analysis.
pop_tracks_df = get_track_info(pop_songs)
pop_tracks_df.head()
# Out:
#    explicit                      id  is_local  \
# 0     False  55S2PQgSMYAhgoTCcGCDfw     False
# 1     False  45Egmo7icyopuzJN0oMEdk     False
# 2      True  7dt6x5M1jzdTEt8oCbisTK     False
# 3      True  6FRLCMO5TUHTexlWo8ym1W     False
# 4     False  4hQ6UGyWQIGJmHSo0J88JW     False
#
#                                                 name  popularity  \
# 0                                         Youngblood          90
# 1                           Love Lies (with Normani)          89
# 2                                         Better Now          96
# 3                     Girls Like You (feat. Cardi B)          94
# 4  Back To You - From 13 Reasons Why – Season 2 S...          88
#
#                                          preview_url  track_number
# 0                                               None             1
# 1  https://p.scdn.co/mp3-preview/d53d5678b946219b...             1
# 2                                               None             9
# 3                                               None             1
# 4                                               None             1

# %%
# Get features of Pop songs foor later analyis.
pop_features = feature_analyzer(pop_tracks_df['id'])
pop_features.head()
# Out:
#    acousticness  danceability  duration_ms  energy                      id  \
# 0        0.0169         0.596       203418   0.854  55S2PQgSMYAhgoTCcGCDfw
# 1        0.0956         0.708       201707   0.648  45Egmo7icyopuzJN0oMEdk
# 2        0.3540         0.680       231267   0.563  7dt6x5M1jzdTEt8oCbisTK
# 3        0.5680         0.851       235545   0.541  6FRLCMO5TUHTexlWo8ym1W
# 4        0.0945         0.601       207905   0.724  4hQ6UGyWQIGJmHSo0J88JW
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000000    7     0.124    -5.114     0       0.4630  120.274
# 1          0.000000    6     0.134    -5.626     1       0.0449  143.955
# 2          0.000000   10     0.136    -5.843     1       0.0454  145.028
# 3          0.000000    0     0.130    -6.825     1       0.0505  124.959
# 4          0.000002    6     0.120    -4.856     1       0.0486  102.061
#
#    time_signature  valence
# 0               4    0.152
# 1               4    0.338
# 2               4    0.374
# 3               4    0.448
# 4               4    0.508

# %%
# Merge Pop
pop_df = pd.merge(pop_tracks_df, pop_features, how='outer', on='id')
pop_df['genre']='pop'
pop_df.head()
# Out:
#    explicit                      id  is_local  \
# 0     False  55S2PQgSMYAhgoTCcGCDfw     False
# 1     False  45Egmo7icyopuzJN0oMEdk     False
# 2      True  7dt6x5M1jzdTEt8oCbisTK     False
# 3      True  6FRLCMO5TUHTexlWo8ym1W     False
# 4     False  4hQ6UGyWQIGJmHSo0J88JW     False
#
#                                                 name  popularity  \
# 0                                         Youngblood          90
# 1                           Love Lies (with Normani)          89
# 2                                         Better Now          96
# 3                     Girls Like You (feat. Cardi B)          94
# 4  Back To You - From 13 Reasons Why – Season 2 S...          88
#
#                                          preview_url  track_number  \
# 0                                               None             1
# 1  https://p.scdn.co/mp3-preview/d53d5678b946219b...             1
# 2                                               None             9
# 3                                               None             1
# 4                                               None             1
#
#    acousticness  danceability  duration_ms  ...    instrumentalness  key  \
# 0        0.0169         0.596       203418  ...            0.000000    7
# 1        0.0956         0.708       201707  ...            0.000000    6
# 2        0.3540         0.680       231267  ...            0.000000   10
# 3        0.5680         0.851       235545  ...            0.000000    0
# 4        0.0945         0.601       207905  ...            0.000002    6
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0     0.124    -5.114     0       0.4630  120.274               4    0.152
# 1     0.134    -5.626     1       0.0449  143.955               4    0.338
# 2     0.136    -5.843     1       0.0454  145.028               4    0.374
# 3     0.130    -6.825     1       0.0505  124.959               4    0.448
# 4     0.120    -4.856     1       0.0486  102.061               4    0.508
#
#    genre
# 0    pop
# 1    pop
# 2    pop
# 3    pop
# 4    pop
#
# [5 rows x 21 columns]

# %%
# Merge all geners into 1 df. Not looking at the pop charts for Project one analysis.
all_genres_df=pd.concat([hot_df, country_df, rap_df], axis=0)
all_genres_df.head()
# Out:
#    explicit                      id  is_local                            name  \
# 0      True  6FRLCMO5TUHTexlWo8ym1W     False  Girls Like You (feat. Cardi B)
# 1      True  0s3nnoMeVWz3989MkNQiRf     False                    Lucid Dreams
# 2      True  7dt6x5M1jzdTEt8oCbisTK     False                      Better Now
# 3      True  7dt6x5M1jzdTEt8oCbisTK     False                      Better Now
# 4      True  7dt6x5M1jzdTEt8oCbisTK     False                      Better Now
#
#    popularity preview_url  track_number  acousticness  danceability  \
# 0          94        None             1         0.568         0.851
# 1          98        None             3         0.349         0.511
# 2          96        None             9         0.354         0.680
# 3          96        None             9         0.354         0.680
# 4          96        None             9         0.354         0.680
#
#    duration_ms   ...     instrumentalness  key  liveness  loudness  mode  \
# 0       235545   ...                  0.0    0     0.130    -6.825     1
# 1       239836   ...                  0.0    6     0.340    -7.230     0
# 2       231267   ...                  0.0   10     0.136    -5.843     1
# 3       231267   ...                  0.0   10     0.136    -5.843     1
# 4       231267   ...                  0.0   10     0.136    -5.843     1
#
#    speechiness    tempo  time_signature  valence    genre
# 0       0.0505  124.959               4    0.448  hot-100
# 1       0.2000   83.903               4    0.218  hot-100
# 2       0.0454  145.028               4    0.374  hot-100
# 3       0.0454  145.028               4    0.374  hot-100
# 4       0.0454  145.028               4    0.374  hot-100
#
# [5 rows x 21 columns]

# %%
# T test for country vs rap popularity
stats.ttest_ind(country_track_df['popularity'], rap_tracks_df['popularity'])
# Out:
# Ttest_indResult(statistic=-10.894301412816157, pvalue=5.836396256513532e-17)

# %%
# T test for country vs rap speechiness
stats.ttest_ind(country_features['speechiness'], rap_features['speechiness'])
# Out:
# Ttest_indResult(statistic=-7.004681218321615, pvalue=1.0211720687991313e-09)

# %%
# T test for valence country vs hot 100 valence
stats.ttest_ind(country_df['valence'], hot_df['valence'])
# Out:
# Ttest_indResult(statistic=4.063861028503139, pvalue=7.715122387218039e-05)

# %%
# Define a function to create scatter plots of the audio feaetures. Saves time for making consistent scatter plot formats.
def musicScatPlotter(x_variable, y_variable):
    '''Takes the column names of the variables you want to plot as strings and makes a scatter plot. 
    It compares those relations ships for the Billboard Hot-100, Country, and Rap Charts.'''
    # Variable to hold alpha value
    alpha=0.9
    # Increase DPI for higher res plots.
    plt.figure(dpi=200)
    
    # Plot data
    plt.scatter(x=hot_df[x_variable], y=hot_df[y_variable], c='lightsalmon', edgecolors='k', alpha=alpha)
    plt.scatter(x=country_df[x_variable], y=country_df[y_variable], c='cornflowerblue', marker='s', edgecolors='k', alpha=alpha)
    plt.scatter(x=rap_df[x_variable], y=rap_df[y_variable], c='lightgray', marker='D', edgecolors='k', alpha=alpha)
    
    # Label chart axes
    plt.xlabel(x_variable.title())
    plt.ylabel(y_variable.title())
    
    # Add legend
    plt.legend(['Hot-100','Country','Rap'], loc='best')
    title = f'{y_variable.title()} vs {x_variable.title()}'
    plt.title(f'{title}')
    
    # Save figure
    plt.savefig(f'Images/{title}.png')

# %%
# Print the columns to see what relationships we can explore
hot_df.columns
# Out:
# Index(['explicit', 'id', 'is_local', 'name', 'popularity', 'preview_url',
#        'track_number', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'genre'],
#       dtype='object')

# %%
# Valence vs Popularity
musicScatPlotter('valence', 'popularity')

# %%
# Danceability vs Popularity
musicScatPlotter('danceability', 'popularity')
# plt.ylim(0)

# %%
musicScatPlotter('energy', 'popularity')

# %%
musicScatPlotter('valence', 'energy')

# %%
musicScatPlotter('valence', 'danceability')

# %%
musicScatPlotter('tempo', 'danceability')

# %%
# Is there a relatonshiop between Danceability and song length?
musicScatPlotter('duration_ms', 'danceability')

# %%
# Which is more Danceable?
genre_means = all_genres_df.groupby('genre').mean()
genre_se = all_genres_df.groupby('genre').sem()
genre_means
# Out:
#          explicit  is_local  popularity  track_number  acousticness  \
# genre
# country  0.080000       0.0   73.000000      4.380000      0.190708
# hot-100  0.548077       0.0   87.528846      3.798077      0.182076
# rap      0.960000       0.0   91.640000      3.520000      0.119046
#
#          danceability    duration_ms    energy  instrumentalness       key  \
# genre
# country      0.579340  202960.420000  0.732500          0.000102  6.400000
# hot-100      0.690365  213319.740385  0.638808          0.000286  5.548077
# rap          0.816800  215218.360000  0.616520          0.000735  4.760000
#
#          liveness  loudness      mode  speechiness       tempo  \
# genre
# country  0.172960 -5.300860  0.900000     0.054984  122.686920
# hot-100  0.163096 -6.148356  0.711538     0.133388  124.650971
# rap      0.212760 -6.381120  0.520000     0.197800  128.474120
#
#          time_signature   valence
# genre
# country        4.000000  0.570560
# hot-100        4.019231  0.431849
# rap            4.000000  0.449640

# %%
# Anova for danceability
stats.f_oneway(hot_df['danceability'], country_df['danceability'], rap_df['danceability'])
# Out:
# F_onewayResult(statistic=32.27949530703705, pvalue=1.1418645800314327e-12)

# %%
# Anova for valence
stats.f_oneway(hot_df['valence'], country_df['valence'], rap_df['valence'])
# Out:
# F_onewayResult(statistic=8.677859895207273, pvalue=0.00025450520935149917)

# %%
# Put the genres/chart names into a list to be the categories for bar charts
genres= []
for genre in genre_means.index:
    genres.append(genre.title())
    print(genre)
# Out:
# country
# hot-100
# rap

# %%
# Plot bar graph
plt.figure(dpi=200)
plt.bar(x=genres, height=genre_means['danceability'], yerr=genre_se['danceability'], color=['lightsalmon','cornflowerblue','lightgray'], capsize=3)
plt.ylabel('Danceability')
plt.xlabel('Genre')
plt.title('Danceability Scores for the Top Artists on \n Country, Hot-100, and Rap Charts')
plt.savefig('Images/Genre_Danceability_Bar_Chart.png')

# %%
# Plot bar graph for valence
plt.figure(dpi=200)
plt.bar(x=genres, height=genre_means['valence'], yerr=genre_se['valence'], color=['lightsalmon','cornflowerblue','lightgray'], capsize=3)
plt.ylabel('Valence')
plt.xlabel('Genre')
plt.title('Valence Scores for the Top Artists on \n Country, Hot-100, and Rap Charts')

# Plot horizontal line at 0.5 to indicate a neutral valence
plt.hlines(y=0.5, xmin=0, xmax=2, linestyles='--', label='Neutral Line')

plt.savefig('Images/Genre_Valence_Bar_Chart.png')

# %% [markdown]
# ## Experimental analysis beyond initial scope of project
# ### Do certain genres prefer certain keys?
#
# * Rename Spotify's integer key designation with the actual music
# * Count the frequency of each key
# * Run Chi Square test to see if there's a difference in the occurence of song keys

# %%
# Define a list to of all the note names in the Western music system
key_names = ['C', 'C\u266F/D\u266D', 'D', 'D\u266F/E\u266D',
           'E', 'F', 'F\u266F/G\u266D', 'G', 'G\u266F/A\u266D',
           'A', 'A\u266F/B\u266D', 'B']
print(key_names)
# Out:
# ['C', 'C♯/D♭', 'D', 'D♯/E♭', 'E', 'F', 'F♯/G♭', 'G', 'G♯/A♭', 'A', 'A♯/B♭', 'B']

# %%
# Define new column to get the actual key names
all_genres_df['key name'] = [key_names[key] for key in all_genres_df['key']]
all_genres_df.head()
# Out:
#    explicit                      id  is_local                            name  \
# 0      True  6FRLCMO5TUHTexlWo8ym1W     False  Girls Like You (feat. Cardi B)
# 1      True  0s3nnoMeVWz3989MkNQiRf     False                    Lucid Dreams
# 2      True  7dt6x5M1jzdTEt8oCbisTK     False                      Better Now
# 3      True  7dt6x5M1jzdTEt8oCbisTK     False                      Better Now
# 4      True  7dt6x5M1jzdTEt8oCbisTK     False                      Better Now
#
#    popularity preview_url  track_number  acousticness  danceability  \
# 0          94        None             1         0.568         0.851
# 1          98        None             3         0.349         0.511
# 2          96        None             9         0.354         0.680
# 3          96        None             9         0.354         0.680
# 4          96        None             9         0.354         0.680
#
#    duration_ms    ...     key  liveness  loudness  mode  speechiness    tempo  \
# 0       235545    ...       0     0.130    -6.825     1       0.0505  124.959
# 1       239836    ...       6     0.340    -7.230     0       0.2000   83.903
# 2       231267    ...      10     0.136    -5.843     1       0.0454  145.028
# 3       231267    ...      10     0.136    -5.843     1       0.0454  145.028
# 4       231267    ...      10     0.136    -5.843     1       0.0454  145.028
#
#    time_signature  valence    genre  key name
# 0               4    0.448  hot-100         C
# 1               4    0.218  hot-100     F♯/G♭
# 2               4    0.374  hot-100     A♯/B♭
# 3               4    0.374  hot-100     A♯/B♭
# 4               4    0.374  hot-100     A♯/B♭
#
# [5 rows x 22 columns]

# %%
# Groupby Count to get the Number of songs in each Key
genreKeys = all_genres_df[['key name','genre','name']].copy()
genreKeys = genreKeys.groupby(['genre', 'key name']).count()
genreKeys = genreKeys.rename(columns={'name':'Song Count'})
genreKeys = genreKeys.reset_index()

# Loop through each value and calculate the percentage and expected value for each key
for i in range(len(genreKeys)):
    if genreKeys.loc[i,'genre']== 'country':
        genreKeys.loc[i,'Key Percentage'] = 100*genreKeys.loc[i,'Song Count']/len(country_df)
        genreKeys.loc[i,'Expected Song Count'] = len(country_df)/len(key_names)
    elif genreKeys.loc[i,'genre']== 'hot-100':
        genreKeys.loc[i,'Key Percentage'] = 100*genreKeys.loc[i,'Song Count']/len(hot_df)
        genreKeys.loc[i,'Expected Song Count'] = len(hot_df)/len(key_names)

    else:
        genreKeys.loc[i,'Key Percentage'] = 100*genreKeys.loc[i,'Song Count']/len(rap_df)
        genreKeys.loc[i,'Expected Song Count'] = len(rap_df)/len(key_names)

        # Create a DF for just the percentages
genreKeys = genreKeys.set_index(['genre', 'key name'])
genreKeysPercent = genreKeys.copy()
genreKeysPercent = genreKeys.drop(columns=['Song Count', 'Expected Song Count'])
genreKeysPercent.head()
# Out:
#                   Key Percentage
# genre   key name
# country A                   12.0
#         A♯/B♭                8.0
#         B                   14.0
#         C                    2.0
#         C♯/D♭               12.0

# %%
# Perform Chi Square test on the key distribution to see if differences are significant
keyTest = np.array(genreKeys.xs('hot-100')['Song Count'], genreKeys.xs('rap')['Song Count'])
expected = np.array(genreKeys.xs('country')['Expected Song Count'], genreKeys.xs('rap')['Expected Song Count'])
stats.chisquare(genreKeys.xs('country')['Song Count']) #genreKeys.xs('country')['Expected Song Count'])
# Out:
# Power_divergenceResult(statistic=9.999999999999998, pvalue=0.530387151001041)

# %%
# Group by mode and aggregate by count to get the number of songs for eeach mode (major or minor)
genreMode = all_genres_df[['key name', 'genre', 'mode', 'name']].copy()
genreMode = genreMode.groupby(['genre', 'mode']).count()
genreMode = genreMode.rename(columns={'name':'Song Count'})
genreMode.head()
# Out:
#               key name  Song Count
# genre   mode
# country 0            5           5
#         1           45          45
# hot-100 0           30          30
#         1           74          74
# rap     0           12          12

# %%
# Run Chi square test to see if there's a significant difference in major vs minor mode
stats.chisquare([genreMode.xs('country')['Song Count'], genreMode.xs('hot-100')['Song Count']])
# Out:
# Power_divergenceResult(statistic=array([17.85714286,  7.06722689]), pvalue=array([2.38123768e-05, 7.85066727e-03]))

# %%
genreUnstacked = genreKeysPercent.unstack().T
genreUnstacked = genreUnstacked.reset_index()
genreUnstacked = genreUnstacked.drop(columns='level_0')
genreUnstacked = genreUnstacked.set_index('key name')
genreUnstacked = genreUnstacked.fillna(0)
genreUnstacked = genreUnstacked.T

# %%
genreUnstacked
# Out:
# key name          A      A♯/B♭          B          C      C♯/D♭         D  \
# genre
# country   12.000000   8.000000  14.000000   2.000000  12.000000  4.000000
# hot-100    7.692308  10.576923   8.653846   9.615385  15.384615  7.692308
# rap        4.000000   8.000000   0.000000  12.000000  20.000000  4.000000
#
# key name     D♯/E♭         E          F     F♯/G♭          G  G♯/A♭
# genre
# country   6.000000  8.000000   6.000000  6.000000  14.000000    8.0
# hot-100   1.923077  4.807692   6.730769  5.769231   8.653846   12.5
# rap       0.000000  4.000000  16.000000  8.000000   4.000000   20.0

# %%
fig, ax = plt.subplots(3,1, dpi=300, sharex=True, sharey=True)
ax1 = genreUnstacked.xs('country').plot(kind='bar',ax=ax[0])
ax2 = genreUnstacked.xs('hot-100').plot(kind='bar',ax=ax[1])
ax3 = genreUnstacked.xs('rap').plot(kind='bar',ax=ax[2])
ax1.set_title('Country Key Usage')
ax2.set_title('Hot-100 Key Usage')
ax3.set_title('Rap Key Usage')
fig.text(x=0, y=0.6, s='Percent', ha='center', va='center', rotation='vertical')
plt.tight_layout()

# %% [markdown]
# ## Experimental Analysis
# ### Dig deeper into the audio anylsis section of the Sportify API
#
# * Spotify can provide very detailed analyis of an audio file, but there is little documentation on this ability. Let's play around with it!

# %%
# song_test = 'I wanna dance with somebody (who loves me)'

song_test = input('What song do you want? ')
song_id = sp.search(song_test)['tracks']['items'][0]['id']

pprint(song_id)

song_analysis = sp.audio_analysis(song_id)
# Out:
# What song do you want? simple florida georgia line
# '1co0puPTYvqAdUEjFOjne9'

# %%
# Get artists for track and put them into a list if there's multiple
artists = sp.track(song_id)['artists']
artist_names = []
for artist in artists:
    artist_names.append(artist['name'])
pprint(artist_names)
# Out:
# ['Florida Georgia Line']

# %%
# Print Json response
pprint(song_analysis)
# Out:
# {'bars': [{'confidence': 0.839, 'duration': 1.18145, 'start': 0.32517},
#           {'confidence': 0.17, 'duration': 1.20085, 'start': 1.50663},
#           {'confidence': 0.66, 'duration': 1.19826, 'start': 2.70748},
#           {'confidence': 0.625, 'duration': 1.199, 'start': 3.90574},
#           {'confidence': 0.406, 'duration': 1.20185, 'start': 5.10474},
#           {'confidence': 0.401, 'duration': 1.19949, 'start': 6.30658},
#           {'confidence': 0.554, 'duration': 1.20252, 'start': 7.50608},
#           {'confidence': 0.465, 'duration': 1.20964, 'start': 8.7086},
#           {'confidence': 0.107, 'duration': 1.21836, 'start': 9.91824},
#           {'confidence': 0.606, 'duration': 1.21177, 'start': 11.1366},
#           {'confidence': 0.133, 'duration': 1.20094, 'start': 12.34838},
#           {'confidence': 0.768, 'duration': 1.18686, 'start': 13.54931},
#           {'confidence': 0.823, 'duration': 1.19528, 'start': 14.73617},
#           {'confidence': 0.676, 'duration': 0.30081, 'start': 15.93145},
#           {'confidence': 0.864, 'duration': 1.18784, 'start': 16.23225},
#           {'confidence': 0.73, 'duration': 1.18906, 'start': 17.42009},
#           {'confidence': 0.447, 'duration': 1.21414, 'start': 18.60915},
#           {'confidence': 0.26, 'duration': 1.21346, 'start': 19.82329},
#           {'confidence': 0.051, 'duration': 1.19806, 'start': 21.03675},
#           {'confidence': 0.211, 'duration': 1.19074, 'start': 22.23481},
#           {'confidence': 0.456, 'duration': 1.19339, 'start': 23.42555},
#           {'confidence': 0.445, 'duration': 1.20199, 'start': 24.61893},
#           {'confidence': 0.406, 'duration': 1.18911, 'start': 25.82092},
#           {'confidence': 0.678, 'duration': 1.20357, 'start': 27.01004},
#           {'confidence': 0.612, 'duration': 1.20732, 'start': 28.21361},
#           {'confidence': 0.551, 'duration': 1.20196, 'start': 29.42093},
#           {'confidence': 0.698, 'duration': 1.20895, 'start': 30.62289},
#           {'confidence': 0.495, 'duration': 1.19233, 'start': 31.83184},
#           {'confidence': 0.925, 'duration': 1.19288, 'start': 33.02417},
#           {'confidence': 0.513, 'duration': 1.20173, 'start': 34.21705},
#           {'confidence': 0.266, 'duration': 1.20061, 'start': 35.41878},
#           {'confidence': 0.519, 'duration': 1.19516, 'start': 36.61939},
#           {'confidence': 0.543, 'duration': 1.21031, 'start': 37.81456},
#           {'confidence': 0.799, 'duration': 1.20944, 'start': 39.02487},
#           {'confidence': 0.479, 'duration': 1.203, 'start': 40.23431},
#           {'confidence': 0.579, 'duration': 1.19548, 'start': 41.43731},
#           {'confidence': 0.551, 'duration': 1.20188, 'start': 42.63279},
#           {'confidence': 0.665, 'duration': 1.18998, 'start': 43.83467},
#           {'confidence': 0.374, 'duration': 1.1942, 'start': 45.02464},
#           {'confidence': 0.25, 'duration': 1.1979, 'start': 46.21884},
#           {'confidence': 0.682, 'duration': 1.20507, 'start': 47.41675},
#           {'confidence': 0.213, 'duration': 1.20124, 'start': 48.62182},
#           {'confidence': 0.241, 'duration': 1.20456, 'start': 49.82305},
#           {'confidence': 0.496, 'duration': 1.20099, 'start': 51.02762},
#           {'confidence': 0.278, 'duration': 1.19442, 'start': 52.22861},
#           {'confidence': 0.59, 'duration': 1.19206, 'start': 53.42303},
#           {'confidence': 0.122, 'duration': 1.19741, 'start': 54.61509},
#           {'confidence': 0.418, 'duration': 1.19945, 'start': 55.81249},
#           {'confidence': 0.437, 'duration': 1.21232, 'start': 57.01195},
#           {'confidence': 0.5, 'duration': 1.20688, 'start': 58.22426},
#           {'confidence': 0.562, 'duration': 1.20096, 'start': 59.43114},
#           {'confidence': 0.228, 'duration': 1.20257, 'start': 60.6321},
#           {'confidence': 0.375, 'duration': 1.18734, 'start': 61.83467},
#           {'confidence': 0.553, 'duration': 1.19327, 'start': 63.02201},
#           {'confidence': 0.837, 'duration': 1.20054, 'start': 64.21528},
#           {'confidence': 0.419, 'duration': 1.19817, 'start': 65.41582},
#           {'confidence': 0.519, 'duration': 1.21666, 'start': 66.61399},
#           {'confidence': 0.36, 'duration': 1.20147, 'start': 67.83065},
#           {'confidence': 0.773, 'duration': 1.18864, 'start': 69.03212},
#           {'confidence': 0.423, 'duration': 1.20281, 'start': 70.22076},
#           {'confidence': 0.575, 'duration': 1.20923, 'start': 71.42357},
#           {'confidence': 0.76, 'duration': 1.20602, 'start': 72.6328},
#           {'confidence': 0.719, 'duration': 1.17927, 'start': 73.83882},
#           {'confidence': 0.599, 'duration': 1.19909, 'start': 75.01809},
#           {'confidence': 0.446, 'duration': 1.20586, 'start': 76.21718},
#           {'confidence': 0.614, 'duration': 1.20356, 'start': 77.42304},
#           {'confidence': 0.669, 'duration': 1.20233, 'start': 78.62661},
#           {'confidence': 0.601, 'duration': 1.1907, 'start': 79.82894},
#           {'confidence': 0.647, 'duration': 1.20474, 'start': 81.01963},
#           {'confidence': 0.705, 'duration': 1.19999, 'start': 82.22437},
#           {'confidence': 0.311, 'duration': 1.19153, 'start': 83.42436},
#           {'confidence': 0.478, 'duration': 1.20181, 'start': 84.61589},
#           {'confidence': 0.661, 'duration': 1.21045, 'start': 85.8177},
#           {'confidence': 0.475, 'duration': 1.20493, 'start': 87.02815},
#           {'confidence': 0.566, 'duration': 1.20475, 'start': 88.23307},
#           {'confidence': 0.5, 'duration': 1.20027, 'start': 89.43783},
#           {'confidence': 0.697, 'duration': 1.19601, 'start': 90.6381},
#           {'confidence': 0.744, 'duration': 1.18824, 'start': 91.8341},
#           {'confidence': 0.199, 'duration': 1.19467, 'start': 93.02234},
#           {'confidence': 0.342, 'duration': 1.19545, 'start': 94.21701},
#           {'confidence': 0.537, 'duration': 1.20637, 'start': 95.41246},
#           {'confidence': 0.44, 'duration': 1.20761, 'start': 96.61883},
#           {'confidence': 0.556, 'duration': 1.212, 'start': 97.82645},
#           {'confidence': 0.49, 'duration': 1.18682, 'start': 99.03845},
#           {'confidence': 0.296, 'duration': 1.19863, 'start': 100.22526},
#           {'confidence': 0.503, 'duration': 1.20197, 'start': 101.42389},
#           {'confidence': 0.132, 'duration': 1.18502, 'start': 102.62586},
#           {'confidence': 0.5, 'duration': 1.20747, 'start': 103.81088},
#           {'confidence': 0.128, 'duration': 1.20807, 'start': 105.01835},
#           {'confidence': 0.264, 'duration': 1.20184, 'start': 106.22642},
#           {'confidence': 0.351, 'duration': 1.19965, 'start': 107.42826},
#           {'confidence': 0.515, 'duration': 1.20447, 'start': 108.62791},
#           {'confidence': 0.253, 'duration': 1.1944, 'start': 109.83238},
#           {'confidence': 0.592, 'duration': 1.18994, 'start': 111.02678},
#           {'confidence': 0.388, 'duration': 1.19852, 'start': 112.21672},
#           {'confidence': 0.144, 'duration': 1.20324, 'start': 113.41524},
#           {'confidence': 0.626, 'duration': 1.19554, 'start': 114.61848},
#           {'confidence': 0.714, 'duration': 1.19771, 'start': 115.81402},
#           {'confidence': 0.76, 'duration': 1.20442, 'start': 117.01174},
#           {'confidence': 0.571, 'duration': 1.19235, 'start': 118.21615},
#           {'confidence': 0.913, 'duration': 1.20552, 'start': 119.40851},
#           {'confidence': 0.56, 'duration': 1.2002, 'start': 120.61402},
#           {'confidence': 0.566, 'duration': 1.19539, 'start': 121.81422},
#           {'confidence': 0.603, 'duration': 1.20125, 'start': 123.00961},
#           {'confidence': 0.384, 'duration': 1.21005, 'start': 124.21085},
#           {'confidence': 0.672, 'duration': 1.20734, 'start': 125.42091},
#           {'confidence': 0.448, 'duration': 1.19603, 'start': 126.62824},
#           {'confidence': 0.675, 'duration': 1.20138, 'start': 127.82428},
#           {'confidence': 0.381, 'duration': 1.19923, 'start': 129.02565},
#           {'confidence': 0.669, 'duration': 1.1992, 'start': 130.22489},
#           {'confidence': 0.555, 'duration': 1.19753, 'start': 131.42409},
#           {'confidence': 0.339, 'duration': 1.194, 'start': 132.62161},
#           {'confidence': 0.736, 'duration': 1.20011, 'start': 133.81561},
#           {'confidence': 0.379, 'duration': 1.21264, 'start': 135.01572},
#           {'confidence': 0.733, 'duration': 1.20374, 'start': 136.22836},
#           {'confidence': 0.645, 'duration': 1.1895, 'start': 137.43211},
#           {'confidence': 0.719, 'duration': 1.20845, 'start': 138.62161},
#           {'confidence': 0.722, 'duration': 1.19845, 'start': 139.83006},
#           {'confidence': 0.283, 'duration': 1.18586, 'start': 141.02851},
#           {'confidence': 0.524, 'duration': 1.19974, 'start': 142.21437},
#           {'confidence': 0.375, 'duration': 1.20611, 'start': 143.41412},
#           {'confidence': 0.647, 'duration': 1.20793, 'start': 144.62022},
#           {'confidence': 0.284, 'duration': 1.20838, 'start': 145.82815},
#           {'confidence': 0.361, 'duration': 1.19924, 'start': 147.03653},
#           {'confidence': 0.525, 'duration': 1.19333, 'start': 148.23577},
#           {'confidence': 0.617, 'duration': 1.19067, 'start': 149.4291},
#           {'confidence': 0.292, 'duration': 1.19555, 'start': 150.61977},
#           {'confidence': 0.269, 'duration': 1.19934, 'start': 151.81532},
#           {'confidence': 0.599, 'duration': 1.20208, 'start': 153.01466},
#           {'confidence': 0.303, 'duration': 1.2054, 'start': 154.21674},
#           {'confidence': 0.521, 'duration': 1.20045, 'start': 155.42214},
#           {'confidence': 0.419, 'duration': 1.18883, 'start': 156.6226},
#           {'confidence': 0.637, 'duration': 1.20609, 'start': 157.81142},
#           {'confidence': 0.352, 'duration': 1.20376, 'start': 159.01752},
#           {'confidence': 0.16, 'duration': 1.19016, 'start': 160.22128},
#           {'confidence': 0.376, 'duration': 1.20979, 'start': 161.41144},
#           {'confidence': 0.641, 'duration': 1.20875, 'start': 162.62123},
#           {'confidence': 0.357, 'duration': 1.19508, 'start': 163.82997},
#           {'confidence': 0.698, 'duration': 1.19988, 'start': 165.02505},
#           {'confidence': 0.227, 'duration': 1.20327, 'start': 166.22493},
#           {'confidence': 0.206, 'duration': 1.19479, 'start': 167.4282},
#           {'confidence': 0.609, 'duration': 1.19398, 'start': 168.62299},
#           {'confidence': 0.692, 'duration': 1.20385, 'start': 169.81697},
#           {'confidence': 0.265, 'duration': 1.20631, 'start': 171.02082},
#           {'confidence': 0.467, 'duration': 1.19358, 'start': 172.22713},
#           {'confidence': 0.503, 'duration': 1.2002, 'start': 173.4207},
#           {'confidence': 0.768, 'duration': 1.20767, 'start': 174.62091},
#           {'confidence': 0.546, 'duration': 1.20421, 'start': 175.82858},
#           {'confidence': 0.327, 'duration': 1.19433, 'start': 177.03279},
#           {'confidence': 0.574, 'duration': 1.19353, 'start': 178.22711},
#           {'confidence': 0.581, 'duration': 1.20636, 'start': 179.42064},
#           {'confidence': 0.0, 'duration': 1.24517, 'start': 180.62701}],
#  'beats': [{'confidence': 0.373, 'duration': 0.28239, 'start': 0.32517},
#            {'confidence': 0.942, 'duration': 0.30132, 'start': 0.60756},
#            {'confidence': 0.835, 'duration': 0.30079, 'start': 0.90888},
#            {'confidence': 0.728, 'duration': 0.29696, 'start': 1.20967},
#            {'confidence': 0.481, 'duration': 0.30124, 'start': 1.50663},
#            {'confidence': 0.458, 'duration': 0.30096, 'start': 1.80787},
#            {'confidence': 0.522, 'duration': 0.30041, 'start': 2.10883},
#            {'confidence': 0.41, 'duration': 0.29824, 'start': 2.40923},
#            {'confidence': 0.455, 'duration': 0.29903, 'start': 2.70748},
#            {'confidence': 0.42, 'duration': 0.30037, 'start': 3.00651},
#            {'confidence': 0.437, 'duration': 0.29929, 'start': 3.30688},
#            {'confidence': 0.364, 'duration': 0.29956, 'start': 3.60618},
#            {'confidence': 0.487, 'duration': 0.30036, 'start': 3.90574},
#            {'confidence': 0.496, 'duration': 0.30036, 'start': 4.2061},
#            {'confidence': 0.46, 'duration': 0.29955, 'start': 4.50645},
#            {'confidence': 0.412, 'duration': 0.29874, 'start': 4.806},
#            {'confidence': 0.421, 'duration': 0.30034, 'start': 5.10474},
#            {'confidence': 0.348, 'duration': 0.30221, 'start': 5.40508},
#            {'confidence': 0.391, 'duration': 0.29979, 'start': 5.70729},
#            {'confidence': 0.352, 'duration': 0.29951, 'start': 6.00708},
#            {'confidence': 0.419, 'duration': 0.3003, 'start': 6.30658},
#            {'confidence': 0.461, 'duration': 0.30055, 'start': 6.60688},
#            {'confidence': 0.422, 'duration': 0.30027, 'start': 6.90744},
#            {'confidence': 0.405, 'duration': 0.29838, 'start': 7.2077},
#            {'confidence': 0.457, 'duration': 0.29998, 'start': 7.50608},
#            {'confidence': 0.394, 'duration': 0.30104, 'start': 7.80605},
#            {'confidence': 0.394, 'duration': 0.3013, 'start': 8.10709},
#            {'confidence': 0.369, 'duration': 0.30021, 'start': 8.40839},
#            {'confidence': 0.461, 'duration': 0.30101, 'start': 8.7086},
#            {'confidence': 0.42, 'duration': 0.30369, 'start': 9.00961},
#            {'confidence': 0.466, 'duration': 0.30261, 'start': 9.3133},
#            {'confidence': 0.458, 'duration': 0.30233, 'start': 9.61591},
#            {'confidence': 0.471, 'duration': 0.30474, 'start': 9.91824},
#            {'confidence': 0.418, 'duration': 0.30339, 'start': 10.22298},
#            {'confidence': 0.325, 'duration': 0.30526, 'start': 10.52636},
#            {'confidence': 0.396, 'duration': 0.30498, 'start': 10.83162},
#            {'confidence': 0.343, 'duration': 0.30121, 'start': 11.1366},
#            {'confidence': 0.393, 'duration': 0.3063, 'start': 11.43781},
#            {'confidence': 0.3, 'duration': 0.30361, 'start': 11.74412},
#            {'confidence': 0.302, 'duration': 0.30065, 'start': 12.04772},
#            {'confidence': 0.226, 'duration': 0.30091, 'start': 12.34838},
#            {'confidence': 0.351, 'duration': 0.29822, 'start': 12.64929},
#            {'confidence': 0.368, 'duration': 0.29929, 'start': 12.94751},
#            {'confidence': 0.403, 'duration': 0.30251, 'start': 13.24681},
#            {'confidence': 0.485, 'duration': 0.29633, 'start': 13.54931},
#            {'confidence': 0.427, 'duration': 0.29605, 'start': 13.84564},
#            {'confidence': 0.343, 'duration': 0.29711, 'start': 14.14169},
#            {'confidence': 0.325, 'duration': 0.29737, 'start': 14.4388},
#            {'confidence': 0.343, 'duration': 0.30085, 'start': 14.73617},
#            {'confidence': 0.424, 'duration': 0.29815, 'start': 15.03702},
#            {'confidence': 0.339, 'duration': 0.29653, 'start': 15.33517},
#            {'confidence': 0.303, 'duration': 0.29974, 'start': 15.63171},
#            {'confidence': 0.345, 'duration': 0.30081, 'start': 15.93145},
#            {'confidence': 0.339, 'duration': 0.29811, 'start': 16.23225},
#            {'confidence': 0.248, 'duration': 0.2973, 'start': 16.53037},
#            {'confidence': 0.316, 'duration': 0.29461, 'start': 16.82767},
#            {'confidence': 0.258, 'duration': 0.29782, 'start': 17.12227},
#            {'confidence': 0.26, 'duration': 0.29781, 'start': 17.42009},
#            {'confidence': 0.306, 'duration': 0.29593, 'start': 17.71791},
#            {'confidence': 0.418, 'duration': 0.29619, 'start': 18.01383},
#            {'confidence': 0.515, 'duration': 0.29913, 'start': 18.31002},
#            {'confidence': 0.561, 'duration': 0.30234, 'start': 18.60915},
#            {'confidence': 0.61, 'duration': 0.30394, 'start': 18.91149},
#            {'confidence': 0.623, 'duration': 0.30286, 'start': 19.21543},
#            {'confidence': 0.621, 'duration': 0.305, 'start': 19.51829},
#            {'confidence': 0.534, 'duration': 0.30204, 'start': 19.82329},
#            {'confidence': 0.421, 'duration': 0.3023, 'start': 20.12532},
#            {'confidence': 0.299, 'duration': 0.30604, 'start': 20.42762},
#            {'confidence': 0.248, 'duration': 0.30308, 'start': 20.73366},
#            {'confidence': 0.259, 'duration': 0.29959, 'start': 21.03675},
#            {'confidence': 0.176, 'duration': 0.30012, 'start': 21.33634},
#            {'confidence': 0.266, 'duration': 0.29717, 'start': 21.63646},
#            {'confidence': 0.298, 'duration': 0.30118, 'start': 21.93363},
#            {'confidence': 0.365, 'duration': 0.30064, 'start': 22.23481},
#            {'confidence': 0.328, 'duration': 0.29581, 'start': 22.53545},
#            {'confidence': 0.391, 'duration': 0.29446, 'start': 22.83126},
#            {'confidence': 0.302, 'duration': 0.29982, 'start': 23.12573},
#            {'confidence': 0.411, 'duration': 0.29526, 'start': 23.42555},
#            {'confidence': 0.379, 'duration': 0.29821, 'start': 23.72081},
#            {'confidence': 0.301, 'duration': 0.29982, 'start': 24.01902},
#            {'confidence': 0.258, 'duration': 0.30009, 'start': 24.31884},
#            {'confidence': 0.321, 'duration': 0.3009, 'start': 24.61893},
#            {'confidence': 0.284, 'duration': 0.3017, 'start': 24.91983},
#            {'confidence': 0.334, 'duration': 0.29849, 'start': 25.22154},
#            {'confidence': 0.365, 'duration': 0.3009, 'start': 25.52002},
#            {'confidence': 0.35, 'duration': 0.29822, 'start': 25.82092},
#            {'confidence': 0.328, 'duration': 0.29688, 'start': 26.11914},
#            {'confidence': 0.316, 'duration': 0.29688, 'start': 26.41602},
#            {'confidence': 0.32, 'duration': 0.29714, 'start': 26.7129},
#            {'confidence': 0.376, 'duration': 0.29902, 'start': 27.01004},
#            {'confidence': 0.42, 'duration': 0.29955, 'start': 27.30906},
#            {'confidence': 0.499, 'duration': 0.30223, 'start': 27.60861},
#            {'confidence': 0.48, 'duration': 0.30277, 'start': 27.91084},
#            {'confidence': 0.501, 'duration': 0.30331, 'start': 28.21361},
#            {'confidence': 0.453, 'duration': 0.30277, 'start': 28.51692},
#            {'confidence': 0.386, 'duration': 0.30089, 'start': 28.81968},
#            {'confidence': 0.351, 'duration': 0.30036, 'start': 29.12058},
#            {'confidence': 0.291, 'duration': 0.30143, 'start': 29.42093},
#            {'confidence': 0.231, 'duration': 0.29875, 'start': 29.72236},
#            {'confidence': 0.165, 'duration': 0.30089, 'start': 30.02111},
#            {'confidence': 0.138, 'duration': 0.30089, 'start': 30.322},
#            {'confidence': 0.163, 'duration': 0.3017, 'start': 30.62289},
#            {'confidence': 0.215, 'duration': 0.30465, 'start': 30.92459},
#            {'confidence': 0.269, 'duration': 0.30331, 'start': 31.22924},
#            {'confidence': 0.343, 'duration': 0.29929, 'start': 31.53255},
#            {'confidence': 0.344, 'duration': 0.30063, 'start': 31.83184},
#            {'confidence': 0.295, 'duration': 0.29741, 'start': 32.13247},
#            {'confidence': 0.221, 'duration': 0.29714, 'start': 32.42988},
#            {'confidence': 0.232, 'duration': 0.29714, 'start': 32.72703},
#            {'confidence': 0.212, 'duration': 0.29768, 'start': 33.02417},
#            {'confidence': 0.182, 'duration': 0.29768, 'start': 33.32185},
#            {'confidence': 0.215, 'duration': 0.29849, 'start': 33.61954},
#            {'confidence': 0.284, 'duration': 0.29903, 'start': 33.91803},
#            {'confidence': 0.238, 'duration': 0.30037, 'start': 34.21705},
#            {'confidence': 0.227, 'duration': 0.29983, 'start': 34.51742},
#            {'confidence': 0.233, 'duration': 0.30278, 'start': 34.81725},
#            {'confidence': 0.246, 'duration': 0.29875, 'start': 35.12003},
#            {'confidence': 0.215, 'duration': 0.30036, 'start': 35.41878},
#            {'confidence': 0.188, 'duration': 0.3017, 'start': 35.71914},
#            {'confidence': 0.208, 'duration': 0.29955, 'start': 36.02084},
#            {'confidence': 0.256, 'duration': 0.29901, 'start': 36.32039},
#            {'confidence': 0.269, 'duration': 0.299, 'start': 36.61939},
#            {'confidence': 0.225, 'duration': 0.29658, 'start': 36.9184},
#            {'confidence': 0.266, 'duration': 0.29979, 'start': 37.21498},
#            {'confidence': 0.335, 'duration': 0.29979, 'start': 37.51477},
#            {'confidence': 0.299, 'duration': 0.30031, 'start': 37.81456},
#            {'confidence': 0.391, 'duration': 0.30298, 'start': 38.11487},
#            {'confidence': 0.355, 'duration': 0.30351, 'start': 38.41785},
#            {'confidence': 0.383, 'duration': 0.3035, 'start': 38.72137},
#            {'confidence': 0.34, 'duration': 0.30216, 'start': 39.02487},
#            {'confidence': 0.272, 'duration': 0.30269, 'start': 39.32703},
#            {'confidence': 0.269, 'duration': 0.30135, 'start': 39.62973},
#            {'confidence': 0.297, 'duration': 0.30323, 'start': 39.93108},
#            {'confidence': 0.294, 'duration': 0.30162, 'start': 40.23431},
#            {'confidence': 0.28, 'duration': 0.30108, 'start': 40.53593},
#            {'confidence': 0.254, 'duration': 0.30028, 'start': 40.83701},
#            {'confidence': 0.295, 'duration': 0.30001, 'start': 41.13729},
#            {'confidence': 0.294, 'duration': 0.2976, 'start': 41.43731},
#            {'confidence': 0.298, 'duration': 0.30028, 'start': 41.7349},
#            {'confidence': 0.302, 'duration': 0.29733, 'start': 42.03518},
#            {'confidence': 0.26, 'duration': 0.30028, 'start': 42.33251},
#            {'confidence': 0.209, 'duration': 0.30081, 'start': 42.63279},
#            {'confidence': 0.174, 'duration': 0.29973, 'start': 42.9336},
#            {'confidence': 0.15, 'duration': 0.30027, 'start': 43.23334},
#            {'confidence': 0.253, 'duration': 0.30106, 'start': 43.5336},
#            {'confidence': 0.284, 'duration': 0.29918, 'start': 43.83467},
#            {'confidence': 0.26, 'duration': 0.29917, 'start': 44.13384},
#            {'confidence': 0.269, 'duration': 0.29622, 'start': 44.43302},
#            {'confidence': 0.291, 'duration': 0.29541, 'start': 44.72923},
#            {'confidence': 0.24, 'duration': 0.29969, 'start': 45.02464},
#            {'confidence': 0.202, 'duration': 0.29969, 'start': 45.32433},
#            {'confidence': 0.143, 'duration': 0.29754, 'start': 45.62402},
#            {'confidence': 0.174, 'duration': 0.29727, 'start': 45.92157},
#            {'confidence': 0.239, 'duration': 0.29807, 'start': 46.21884},
#            {'confidence': 0.186, 'duration': 0.29834, 'start': 46.51692},
#            {'confidence': 0.216, 'duration': 0.30155, 'start': 46.81526},
#            {'confidence': 0.319, 'duration': 0.29994, 'start': 47.11681},
#            {'confidence': 0.305, 'duration': 0.29913, 'start': 47.41675},
#            {'confidence': 0.316, 'duration': 0.30234, 'start': 47.71588},
#            {'confidence': 0.258, 'duration': 0.30207, 'start': 48.01822},
#            {'confidence': 0.287, 'duration': 0.30153, 'start': 48.32029},
#            {'confidence': 0.228, 'duration': 0.30152, 'start': 48.62182},
#            {'confidence': 0.211, 'duration': 0.30018, 'start': 48.92334},
#            {'confidence': 0.151, 'duration': 0.30098, 'start': 49.22352},
#            {'confidence': 0.161, 'duration': 0.29856, 'start': 49.5245},
#            {'confidence': 0.168, 'duration': 0.29988, 'start': 49.82305},
#            {'confidence': 0.212, 'duration': 0.30148, 'start': 50.12294},
#            {'confidence': 0.227, 'duration': 0.30147, 'start': 50.42442},
#            {'confidence': 0.203, 'duration': 0.30173, 'start': 50.72589},
#            {'confidence': 0.251, 'duration': 0.30037, 'start': 51.02762},
#            {'confidence': 0.357, 'duration': 0.29821, 'start': 51.32799},
#            {'confidence': 0.292, 'duration': 0.30275, 'start': 51.6262},
#            {'confidence': 0.321, 'duration': 0.29966, 'start': 51.92895},
#            {'confidence': 0.263, 'duration': 0.29833, 'start': 52.22861},
#            {'confidence': 0.218, 'duration': 0.2986, 'start': 52.52694},
#            {'confidence': 0.193, 'duration': 0.29888, 'start': 52.82554},
#            {'confidence': 0.19, 'duration': 0.29861, 'start': 53.12441},
#            {'confidence': 0.232, 'duration': 0.29942, 'start': 53.42303},
#            {'confidence': 0.271, 'duration': 0.29702, 'start': 53.72245},
#            {'confidence': 0.205, 'duration': 0.29715, 'start': 54.01946},
#            {'confidence': 0.231, 'duration': 0.29847, 'start': 54.31662},
#            {'confidence': 0.212, 'duration': 0.30005, 'start': 54.61509},
#            {'confidence': 0.295, 'duration': 0.29976, 'start': 54.91514},
#            {'confidence': 0.223, 'duration': 0.29867, 'start': 55.2149},
#            {'confidence': 0.27, 'duration': 0.29892, 'start': 55.51357},
#            {'confidence': 0.274, 'duration': 0.29916, 'start': 55.81249},
#            {'confidence': 0.281, 'duration': 0.30047, 'start': 56.11165},
#            {'confidence': 0.2, 'duration': 0.30045, 'start': 56.41213},
#            {'confidence': 0.236, 'duration': 0.29937, 'start': 56.71258},
#            {'confidence': 0.211, 'duration': 0.29988, 'start': 57.01195},
#            {'confidence': 0.246, 'duration': 0.30201, 'start': 57.31183},
#            {'confidence': 0.267, 'duration': 0.30468, 'start': 57.61384},
#            {'confidence': 0.253, 'duration': 0.30574, 'start': 57.91852},
#            {'confidence': 0.238, 'duration': 0.30306, 'start': 58.22426},
#            {'confidence': 0.31, 'duration': 0.30199, 'start': 58.52733},
#            {'confidence': 0.218, 'duration': 0.30092, 'start': 58.82931},
#            {'confidence': 0.259, 'duration': 0.30091, 'start': 59.13023},
#            {'confidence': 0.301, 'duration': 0.30198, 'start': 59.43114},
#            {'confidence': 0.351, 'duration': 0.30011, 'start': 59.73312},
#            {'confidence': 0.222, 'duration': 0.2993, 'start': 60.03323},
#            {'confidence': 0.269, 'duration': 0.29957, 'start': 60.33253},
#            {'confidence': 0.348, 'duration': 0.30064, 'start': 60.6321},
#            {'confidence': 0.414, 'duration': 0.30198, 'start': 60.93274},
#            {'confidence': 0.394, 'duration': 0.30118, 'start': 61.23472},
#            {'confidence': 0.434, 'duration': 0.29877, 'start': 61.5359},
#            {'confidence': 0.502, 'duration': 0.29663, 'start': 61.83467},
#            {'confidence': 0.468, 'duration': 0.2977, 'start': 62.1313},
#            {'confidence': 0.33, 'duration': 0.2969, 'start': 62.42901},
#            {'confidence': 0.373, 'duration': 0.2961, 'start': 62.72591},
#            {'confidence': 0.295, 'duration': 0.29611, 'start': 63.02201},
#            {'confidence': 0.247, 'duration': 0.29771, 'start': 63.31812},
#            {'confidence': 0.164, 'duration': 0.29905, 'start': 63.61583},
#            {'confidence': 0.202, 'duration': 0.30039, 'start': 63.91489},
#            {'confidence': 0.226, 'duration': 0.29826, 'start': 64.21528},
#            {'confidence': 0.299, 'duration': 0.3012, 'start': 64.51354},
#            {'confidence': 0.314, 'duration': 0.30067, 'start': 64.81474},
#            {'confidence': 0.398, 'duration': 0.30041, 'start': 65.11541},
#            {'confidence': 0.41, 'duration': 0.29907, 'start': 65.41582},
#            {'confidence': 0.523, 'duration': 0.29854, 'start': 65.71489},
#            {'confidence': 0.488, 'duration': 0.29881, 'start': 66.01343},
#            {'confidence': 0.542, 'duration': 0.30175, 'start': 66.31223},
#            {'confidence': 0.447, 'duration': 0.30336, 'start': 66.61399},
#            {'confidence': 0.494, 'duration': 0.30309, 'start': 66.91734},
#            {'confidence': 0.392, 'duration': 0.30417, 'start': 67.22044},
#            {'confidence': 0.369, 'duration': 0.30604, 'start': 67.5246},
#            {'confidence': 0.287, 'duration': 0.30337, 'start': 67.83065},
#            {'confidence': 0.235, 'duration': 0.3007, 'start': 68.13402},
#            {'confidence': 0.29, 'duration': 0.29963, 'start': 68.43472},
#            {'confidence': 0.278, 'duration': 0.29776, 'start': 68.73436},
#            {'confidence': 0.251, 'duration': 0.2983, 'start': 69.03212},
#            {'confidence': 0.217, 'duration': 0.29696, 'start': 69.33042},
#            {'confidence': 0.261, 'duration': 0.29375, 'start': 69.62738},
#            {'confidence': 0.206, 'duration': 0.29963, 'start': 69.92113},
#            {'confidence': 0.185, 'duration': 0.30177, 'start': 70.22076},
#            {'confidence': 0.252, 'duration': 0.30124, 'start': 70.52253},
#            {'confidence': 0.276, 'duration': 0.29936, 'start': 70.82377},
#            {'confidence': 0.325, 'duration': 0.30043, 'start': 71.12313},
#            {'confidence': 0.288, 'duration': 0.30097, 'start': 71.42357},
#            {'confidence': 0.313, 'duration': 0.30418, 'start': 71.72454},
#            {'confidence': 0.259, 'duration': 0.30124, 'start': 72.02872},
#            {'confidence': 0.303, 'duration': 0.30284, 'start': 72.32996},
#            {'confidence': 0.283, 'duration': 0.30284, 'start': 72.6328},
#            {'confidence': 0.228, 'duration': 0.30204, 'start': 72.93564},
#            {'confidence': 0.139, 'duration': 0.30124, 'start': 73.23768},
#            {'confidence': 0.183, 'duration': 0.2999, 'start': 73.53892},
#            {'confidence': 0.178, 'duration': 0.29562, 'start': 73.83882},
#            {'confidence': 0.243, 'duration': 0.29535, 'start': 74.13444},
#            {'confidence': 0.282, 'duration': 0.29401, 'start': 74.42979},
#            {'confidence': 0.276, 'duration': 0.29428, 'start': 74.7238},
#            {'confidence': 0.266, 'duration': 0.29669, 'start': 75.01809},
#            {'confidence': 0.344, 'duration': 0.2991, 'start': 75.31478},
#            {'confidence': 0.308, 'duration': 0.30098, 'start': 75.61388},
#            {'confidence': 0.33, 'duration': 0.30232, 'start': 75.91486},
#            {'confidence': 0.265, 'duration': 0.30259, 'start': 76.21718},
#            {'confidence': 0.251, 'duration': 0.30046, 'start': 76.51977},
#            {'confidence': 0.164, 'duration': 0.301, 'start': 76.82023},
#            {'confidence': 0.117, 'duration': 0.30181, 'start': 77.12123},
#            {'confidence': 0.162, 'duration': 0.30021, 'start': 77.42304},
#            {'confidence': 0.188, 'duration': 0.29968, 'start': 77.72325},
#            {'confidence': 0.243, 'duration': 0.3021, 'start': 78.02293},
#            {'confidence': 0.307, 'duration': 0.30157, 'start': 78.32503},
#            {'confidence': 0.344, 'duration': 0.30425, 'start': 78.62661},
#            {'confidence': 0.309, 'duration': 0.29997, 'start': 78.93086},
#            {'confidence': 0.292, 'duration': 0.29918, 'start': 79.23083},
#            {'confidence': 0.283, 'duration': 0.29892, 'start': 79.53001},
#            {'confidence': 0.182, 'duration': 0.29866, 'start': 79.82894},
#            {'confidence': 0.156, 'duration': 0.2968, 'start': 80.1276},
#            {'confidence': 0.218, 'duration': 0.29734, 'start': 80.4244},
#            {'confidence': 0.25, 'duration': 0.29789, 'start': 80.72174},
#            {'confidence': 0.241, 'duration': 0.30057, 'start': 81.01963},
#            {'confidence': 0.234, 'duration': 0.30058, 'start': 81.32021},
#            {'confidence': 0.299, 'duration': 0.30058, 'start': 81.62078},
#            {'confidence': 0.287, 'duration': 0.303, 'start': 81.92137},
#            {'confidence': 0.181, 'duration': 0.30086, 'start': 82.22437},
#            {'confidence': 0.243, 'duration': 0.30113, 'start': 82.52523},
#            {'confidence': 0.241, 'duration': 0.29873, 'start': 82.82636},
#            {'confidence': 0.17, 'duration': 0.29927, 'start': 83.12509},
#            {'confidence': 0.19, 'duration': 0.30035, 'start': 83.42436},
#            {'confidence': 0.237, 'duration': 0.29741, 'start': 83.72471},
#            {'confidence': 0.245, 'duration': 0.29528, 'start': 84.02212},
#            {'confidence': 0.305, 'duration': 0.2985, 'start': 84.31739},
#            {'confidence': 0.291, 'duration': 0.29797, 'start': 84.61589},
#            {'confidence': 0.309, 'duration': 0.30092, 'start': 84.91386},
#            {'confidence': 0.361, 'duration': 0.30226, 'start': 85.21478},
#            {'confidence': 0.319, 'duration': 0.30066, 'start': 85.51704},
#            {'confidence': 0.327, 'duration': 0.30441, 'start': 85.8177},
#            {'confidence': 0.306, 'duration': 0.30254, 'start': 86.12211},
#            {'confidence': 0.223, 'duration': 0.30174, 'start': 86.42465},
#            {'confidence': 0.183, 'duration': 0.30175, 'start': 86.7264},
#            {'confidence': 0.219, 'duration': 0.30042, 'start': 87.02815},
#            {'confidence': 0.235, 'duration': 0.30069, 'start': 87.32857},
#            {'confidence': 0.248, 'duration': 0.30284, 'start': 87.62926},
#            {'confidence': 0.285, 'duration': 0.30097, 'start': 87.9321},
#            {'confidence': 0.246, 'duration': 0.30285, 'start': 88.23307},
#            {'confidence': 0.283, 'duration': 0.30152, 'start': 88.53593},
#            {'confidence': 0.306, 'duration': 0.30019, 'start': 88.83745},
#            {'confidence': 0.192, 'duration': 0.30019, 'start': 89.13764},
#            {'confidence': 0.15, 'duration': 0.30153, 'start': 89.43783},
#            {'confidence': 0.207, 'duration': 0.30074, 'start': 89.73936},
#            {'confidence': 0.235, 'duration': 0.2994, 'start': 90.0401},
#            {'confidence': 0.223, 'duration': 0.2986, 'start': 90.3395},
#            {'confidence': 0.228, 'duration': 0.29994, 'start': 90.6381},
#            {'confidence': 0.283, 'duration': 0.30048, 'start': 90.93803},
#            {'confidence': 0.311, 'duration': 0.29967, 'start': 91.23851},
#            {'confidence': 0.205, 'duration': 0.29592, 'start': 91.53818},
#            {'confidence': 0.161, 'duration': 0.29378, 'start': 91.8341},
#            {'confidence': 0.17, 'duration': 0.29726, 'start': 92.12788},
#            {'confidence': 0.203, 'duration': 0.2986, 'start': 92.42515},
#            {'confidence': 0.213, 'duration': 0.2986, 'start': 92.72374},
#            {'confidence': 0.147, 'duration': 0.2986, 'start': 93.02234},
#            {'confidence': 0.198, 'duration': 0.29646, 'start': 93.32094},
#            {'confidence': 0.231, 'duration': 0.29806, 'start': 93.6174},
#            {'confidence': 0.279, 'duration': 0.30155, 'start': 93.91546},
#            {'confidence': 0.311, 'duration': 0.2986, 'start': 94.21701},
#            {'confidence': 0.283, 'duration': 0.29833, 'start': 94.51561},
#            {'confidence': 0.338, 'duration': 0.29886, 'start': 94.81394},
#            {'confidence': 0.253, 'duration': 0.29966, 'start': 95.1128},
#            {'confidence': 0.25, 'duration': 0.30126, 'start': 95.41246},
#            {'confidence': 0.285, 'duration': 0.30314, 'start': 95.71373},
#            {'confidence': 0.242, 'duration': 0.30099, 'start': 96.01686},
#            {'confidence': 0.174, 'duration': 0.30098, 'start': 96.31785},
#            {'confidence': 0.231, 'duration': 0.30044, 'start': 96.61883},
#            {'confidence': 0.264, 'duration': 0.30151, 'start': 96.91927},
#            {'confidence': 0.271, 'duration': 0.3015, 'start': 97.22078},
#            {'confidence': 0.331, 'duration': 0.30417, 'start': 97.52228},
#            {'confidence': 0.304, 'duration': 0.30523, 'start': 97.82645},
#            {'confidence': 0.268, 'duration': 0.30415, 'start': 98.13168},
#            {'confidence': 0.123, 'duration': 0.30306, 'start': 98.43582},
#            {'confidence': 0.154, 'duration': 0.29956, 'start': 98.73888},
#            {'confidence': 0.141, 'duration': 0.30061, 'start': 99.03845},
#            {'confidence': 0.21, 'duration': 0.29899, 'start': 99.33906},
#            {'confidence': 0.219, 'duration': 0.29549, 'start': 99.63805},
#            {'confidence': 0.25, 'duration': 0.29172, 'start': 99.93354},
#            {'confidence': 0.305, 'duration': 0.29466, 'start': 100.22526},
#            {'confidence': 0.272, 'duration': 0.29893, 'start': 100.51992},
#            {'confidence': 0.163, 'duration': 0.30373, 'start': 100.81885},
#            {'confidence': 0.219, 'duration': 0.30132, 'start': 101.12258},
#            {'confidence': 0.241, 'duration': 0.2997, 'start': 101.42389},
#            {'confidence': 0.263, 'duration': 0.30157, 'start': 101.7236},
#            {'confidence': 0.158, 'duration': 0.30129, 'start': 102.02516},
#            {'confidence': 0.202, 'duration': 0.29941, 'start': 102.32645},
#            {'confidence': 0.118, 'duration': 0.29539, 'start': 102.62586},
#            {'confidence': 0.162, 'duration': 0.29485, 'start': 102.92126},
#            {'confidence': 0.198, 'duration': 0.29538, 'start': 103.21611},
#            {'confidence': 0.242, 'duration': 0.29939, 'start': 103.51149},
#            {'confidence': 0.279, 'duration': 0.29993, 'start': 103.81088},
#            {'confidence': 0.338, 'duration': 0.3018, 'start': 104.11081},
#            {'confidence': 0.348, 'duration': 0.30287, 'start': 104.41261},
#            {'confidence': 0.311, 'duration': 0.30287, 'start': 104.71548},
#            {'confidence': 0.281, 'duration': 0.30207, 'start': 105.01835},
#            {'confidence': 0.319, 'duration': 0.30262, 'start': 105.32042},
#            {'confidence': 0.226, 'duration': 0.30209, 'start': 105.62304},
#            {'confidence': 0.159, 'duration': 0.30129, 'start': 105.92513},
#            {'confidence': 0.169, 'duration': 0.30077, 'start': 106.22642},
#            {'confidence': 0.178, 'duration': 0.29972, 'start': 106.52719},
#            {'confidence': 0.169, 'duration': 0.3, 'start': 106.82691},
#            {'confidence': 0.241, 'duration': 0.30135, 'start': 107.12691},
#            {'confidence': 0.237, 'duration': 0.30083, 'start': 107.42826},
#            {'confidence': 0.325, 'duration': 0.3003, 'start': 107.72909},
#            {'confidence': 0.23, 'duration': 0.29925, 'start': 108.02939},
#            {'confidence': 0.292, 'duration': 0.29927, 'start': 108.32864},
#            {'confidence': 0.348, 'duration': 0.30223, 'start': 108.62791},
#            {'confidence': 0.322, 'duration': 0.30385, 'start': 108.93014},
#            {'confidence': 0.203, 'duration': 0.3012, 'start': 109.23399},
#            {'confidence': 0.289, 'duration': 0.2972, 'start': 109.53518},
#            {'confidence': 0.252, 'duration': 0.29776, 'start': 109.83238},
#            {'confidence': 0.28, 'duration': 0.30046, 'start': 110.13014},
#            {'confidence': 0.28, 'duration': 0.29968, 'start': 110.43061},
#            {'confidence': 0.233, 'duration': 0.29649, 'start': 110.73029},
#            {'confidence': 0.281, 'duration': 0.29518, 'start': 111.02678},
#            {'confidence': 0.298, 'duration': 0.29654, 'start': 111.32196},
#            {'confidence': 0.222, 'duration': 0.29924, 'start': 111.6185},
#            {'confidence': 0.214, 'duration': 0.29899, 'start': 111.91774},
#            {'confidence': 0.176, 'duration': 0.29766, 'start': 112.21672},
#            {'confidence': 0.244, 'duration': 0.29956, 'start': 112.51439},
#            {'confidence': 0.198, 'duration': 0.30011, 'start': 112.81394},
#            {'confidence': 0.262, 'duration': 0.30119, 'start': 113.11405},
#            {'confidence': 0.296, 'duration': 0.30066, 'start': 113.41524},
#            {'confidence': 0.323, 'duration': 0.30148, 'start': 113.7159},
#            {'confidence': 0.241, 'duration': 0.30068, 'start': 114.01738},
#            {'confidence': 0.308, 'duration': 0.30042, 'start': 114.31806},
#            {'confidence': 0.282, 'duration': 0.29935, 'start': 114.61848},
#            {'confidence': 0.274, 'duration': 0.29908, 'start': 114.91783},
#            {'confidence': 0.302, 'duration': 0.29828, 'start': 115.21692},
#            {'confidence': 0.278, 'duration': 0.29882, 'start': 115.5152},
#            {'confidence': 0.255, 'duration': 0.29775, 'start': 115.81402},
#            {'confidence': 0.268, 'duration': 0.29936, 'start': 116.11178},
#            {'confidence': 0.345, 'duration': 0.2999, 'start': 116.41114},
#            {'confidence': 0.401, 'duration': 0.3007, 'start': 116.71104},
#            {'confidence': 0.421, 'duration': 0.30097, 'start': 117.01174},
#            {'confidence': 0.432, 'duration': 0.30151, 'start': 117.31271},
#            {'confidence': 0.438, 'duration': 0.30097, 'start': 117.61421},
#            {'confidence': 0.478, 'duration': 0.30097, 'start': 117.91518},
#            {'confidence': 0.424, 'duration': 0.29829, 'start': 118.21615},
#            {'confidence': 0.387, 'duration': 0.29856, 'start': 118.51444},
#            {'confidence': 0.366, 'duration': 0.29748, 'start': 118.813},
#            {'confidence': 0.364, 'duration': 0.29802, 'start': 119.11049},
#            {'confidence': 0.375, 'duration': 0.2999, 'start': 119.40851},
#            {'confidence': 0.342, 'duration': 0.30071, 'start': 119.70841},
#            {'confidence': 0.365, 'duration': 0.30205, 'start': 120.00912},
#            {'confidence': 0.399, 'duration': 0.30286, 'start': 120.31117},
#            {'confidence': 0.369, 'duration': 0.30072, 'start': 120.61402},
#            {'confidence': 0.353, 'duration': 0.30045, 'start': 120.91474},
#            {'confidence': 0.335, 'duration': 0.29938, 'start': 121.21519},
#            {'confidence': 0.375, 'duration': 0.29965, 'start': 121.51457},
#            {'confidence': 0.377, 'duration': 0.29912, 'start': 121.81422},
#            {'confidence': 0.349, 'duration': 0.29831, 'start': 122.11334},
#            {'confidence': 0.351, 'duration': 0.29804, 'start': 122.41165},
#            {'confidence': 0.362, 'duration': 0.29992, 'start': 122.70969},
#            {'confidence': 0.321, 'duration': 0.30045, 'start': 123.00961},
#            {'confidence': 0.311, 'duration': 0.30152, 'start': 123.31006},
#            {'confidence': 0.305, 'duration': 0.29937, 'start': 123.61158},
#            {'confidence': 0.312, 'duration': 0.2999, 'start': 123.91095},
#            {'confidence': 0.294, 'duration': 0.30205, 'start': 124.21085},
#            {'confidence': 0.322, 'duration': 0.30312, 'start': 124.5129},
#            {'confidence': 0.282, 'duration': 0.30178, 'start': 124.81602},
#            {'confidence': 0.228, 'duration': 0.30311, 'start': 125.11779},
#            {'confidence': 0.208, 'duration': 0.30311, 'start': 125.42091},
#            {'confidence': 0.261, 'duration': 0.30311, 'start': 125.72402},
#            {'confidence': 0.297, 'duration': 0.3023, 'start': 126.02713},
#            {'confidence': 0.341, 'duration': 0.29881, 'start': 126.32943},
#            {'confidence': 0.28, 'duration': 0.29908, 'start': 126.62824},
#            {'confidence': 0.312, 'duration': 0.30122, 'start': 126.92732},
#            {'confidence': 0.334, 'duration': 0.29827, 'start': 127.22854},
#            {'confidence': 0.229, 'duration': 0.29746, 'start': 127.52681},
#            {'confidence': 0.206, 'duration': 0.29827, 'start': 127.82428},
#            {'confidence': 0.26, 'duration': 0.29988, 'start': 128.12254},
#            {'confidence': 0.289, 'duration': 0.30256, 'start': 128.42242},
#            {'confidence': 0.299, 'duration': 0.30068, 'start': 128.72497},
#            {'confidence': 0.296, 'duration': 0.29934, 'start': 129.02565},
#            {'confidence': 0.319, 'duration': 0.30041, 'start': 129.32499},
#            {'confidence': 0.317, 'duration': 0.29961, 'start': 129.6254},
#            {'confidence': 0.188, 'duration': 0.29988, 'start': 129.92501},
#            {'confidence': 0.161, 'duration': 0.29907, 'start': 130.22489},
#            {'confidence': 0.197, 'duration': 0.29799, 'start': 130.52395},
#            {'confidence': 0.227, 'duration': 0.30094, 'start': 130.82195},
#            {'confidence': 0.263, 'duration': 0.3012, 'start': 131.12289},
#            {'confidence': 0.191, 'duration': 0.30093, 'start': 131.42409},
#            {'confidence': 0.218, 'duration': 0.29905, 'start': 131.72502},
#            {'confidence': 0.241, 'duration': 0.29878, 'start': 132.02407},
#            {'confidence': 0.229, 'duration': 0.29877, 'start': 132.32284},
#            {'confidence': 0.23, 'duration': 0.30092, 'start': 132.62161},
#            {'confidence': 0.113, 'duration': 0.29823, 'start': 132.92253},
#            {'confidence': 0.127, 'duration': 0.2985, 'start': 133.22076},
#            {'confidence': 0.145, 'duration': 0.29635, 'start': 133.51926},
#            {'confidence': 0.15, 'duration': 0.29956, 'start': 133.81561},
#            {'confidence': 0.117, 'duration': 0.30036, 'start': 134.11518},
#            {'confidence': 0.133, 'duration': 0.30009, 'start': 134.41554},
#            {'confidence': 0.165, 'duration': 0.30009, 'start': 134.71564},
#            {'confidence': 0.241, 'duration': 0.30169, 'start': 135.01572},
#            {'confidence': 0.332, 'duration': 0.30115, 'start': 135.31742},
#            {'confidence': 0.394, 'duration': 0.30517, 'start': 135.61857},
#            {'confidence': 0.37, 'duration': 0.30463, 'start': 135.92374},
#            {'confidence': 0.416, 'duration': 0.30302, 'start': 136.22836},
#            {'confidence': 0.358, 'duration': 0.30167, 'start': 136.53138},
#            {'confidence': 0.408, 'duration': 0.29953, 'start': 136.83305},
#            {'confidence': 0.372, 'duration': 0.29953, 'start': 137.13258},
#            {'confidence': 0.242, 'duration': 0.29711, 'start': 137.43211},
#            {'confidence': 0.304, 'duration': 0.29604, 'start': 137.72922},
#            {'confidence': 0.416, 'duration': 0.29684, 'start': 138.02526},
#            {'confidence': 0.489, 'duration': 0.29951, 'start': 138.3221},
#            {'confidence': 0.472, 'duration': 0.30031, 'start': 138.62161},
#            {'confidence': 0.524, 'duration': 0.30111, 'start': 138.92192},
#            {'confidence': 0.611, 'duration': 0.30325, 'start': 139.22303},
#            {'confidence': 0.483, 'duration': 0.30378, 'start': 139.52628},
#            {'confidence': 0.297, 'duration': 0.30216, 'start': 139.83006},
#            {'confidence': 0.374, 'duration': 0.30136, 'start': 140.13222},
#            {'confidence': 0.432, 'duration': 0.29707, 'start': 140.43358},
#            {'confidence': 0.276, 'duration': 0.29787, 'start': 140.73064},
#            {'confidence': 0.234, 'duration': 0.29787, 'start': 141.02851},
#            {'confidence': 0.292, 'duration': 0.29492, 'start': 141.32638},
#            {'confidence': 0.275, 'duration': 0.29573, 'start': 141.62131},
#            {'confidence': 0.306, 'duration': 0.29734, 'start': 141.91704},
#            {'confidence': 0.279, 'duration': 0.29814, 'start': 142.21437},
#            {'confidence': 0.289, 'duration': 0.30134, 'start': 142.51251},
#            {'confidence': 0.348, 'duration': 0.30053, 'start': 142.81385},
#            {'confidence': 0.343, 'duration': 0.29973, 'start': 143.11439},
#            {'confidence': 0.311, 'duration': 0.30133, 'start': 143.41412},
#            {'confidence': 0.296, 'duration': 0.3024, 'start': 143.71545},
#            {'confidence': 0.219, 'duration': 0.30105, 'start': 144.01785},
#            {'confidence': 0.19, 'duration': 0.30132, 'start': 144.3189},
#            {'confidence': 0.218, 'duration': 0.30079, 'start': 144.62022},
#            {'confidence': 0.22, 'duration': 0.30292, 'start': 144.92101},
#            {'confidence': 0.258, 'duration': 0.30318, 'start': 145.22393},
#            {'confidence': 0.283, 'duration': 0.30103, 'start': 145.52712},
#            {'confidence': 0.239, 'duration': 0.3013, 'start': 145.82815},
#            {'confidence': 0.283, 'duration': 0.3029, 'start': 146.12945},
#            {'confidence': 0.303, 'duration': 0.30156, 'start': 146.43235},
#            {'confidence': 0.212, 'duration': 0.30263, 'start': 146.73391},
#            {'confidence': 0.139, 'duration': 0.2978, 'start': 147.03653},
#            {'confidence': 0.197, 'duration': 0.30021, 'start': 147.33434},
#            {'confidence': 0.242, 'duration': 0.30101, 'start': 147.63455},
#            {'confidence': 0.216, 'duration': 0.30021, 'start': 147.93556},
#            {'confidence': 0.235, 'duration': 0.29833, 'start': 148.23577},
#            {'confidence': 0.302, 'duration': 0.29887, 'start': 148.53411},
#            {'confidence': 0.355, 'duration': 0.29619, 'start': 148.83297},
#            {'confidence': 0.244, 'duration': 0.29994, 'start': 149.12916},
#            {'confidence': 0.207, 'duration': 0.29699, 'start': 149.4291},
# ...
#            'duration': 185.2,
#            'echoprint_version': 4.12,
#            'echoprintstring': 'eJy1nVmSJSmyRLfkzLAcxv0v4R0lql9VtQgWHykt0q2VmXHDrzvYoGoY-Pd9rn0GhGBBXBZUb8HIFuxugPuiBW5bkLwFLVswuwX7GOCdCXVYMD8DwrctuLP4hNMMiNOCFLwFqVtwL_CCHKoFeViwggHlqxb4YEH5LNBEvWE1A-q3LCjZgt4MaLjEG3owIScLyrFgRANGSBakz4JRLNAkv2FPA6Z3FqRowZgWHGfA8tmC1Cwo0QJm4g37OxakbcHpBpwcLCjLguEtOOcN7mvDAJenBaca4AlpBhRnASHtDSF6C5hjA2ayQDf-hEjuMKAMC3Tjb9jRgMSdG1C6ATk5C2o2QAHegDAtSMmCHgyoOPEbmgsW6KHf0IIFs1hwpgE9RwvmMmC4bkGIFsion6AwbIDM5w3ZGbC-aUGq_4KudP9lC_53nFop_w1tWmAy7l9Ys6j3G-4FXuDF9t_QkwXTG6AQaYCI5hvEJt4wpwExZgs0pG_Yy4Ckj7yBQGbAjBacZEAOzQJZ7Rs0yW-4l39B-UyQGHhCFd1_g-jgE1qtFoxuQCcoGJC3AeIiBrhhgUb7DfWzYFcDZjahBgOWixb0aoGG8w3bgi1p9IYYLMgmyECecBQO3zCWBaLdL3BfjRYcC5zfFmxnwRkGeGeC0vYbkIIG7GZAIJEaINr9BtHBN6xtQNTl35CXBfcCL0jBBEzPAJLSG7gxC3K3oG4DShgW5GMBgu0N1Q8LiHcG7GxAqybAJd_Q67RAg_2Gkw0YbVkwswViYE-YsVowtwFLpPwN_8V8_5sIu3_BFhnwxQKb29oVYbOY4cKwQIWjN5iyw-djAU5iAALQgEuOXxCU8t9AeDVAY_0GkcU3rG5A3NuA5ExQ8fYNaVggAfMGDdgbRNmfkCXJ3iAx8ITyeQtkXW_QXLxBRbY3SHS9QWb7hJqnBb1bMI4BrWwLmjOgM2QGtGTAcJ8FInxvkHG9QTf-BpLNG6bo7xt0gTeI4D5huWzBJeVP6MuCEwzY4ViwpgEnmNCCBbNYsL83QJ2rBXct8QmiKU9wvltQkgV7GPAbpw4WtG5AiNmCVCwY0YCYvAVtWmBWk5UcDJjegOyKBRqwJxRkpAHQGQNisyBvC-qwYFhQVcp-QvuSBbrxN0DQDOjNgO6iBemzIDcLtBjxBoLWGwYpy4DTDZgSP2-Qu7yheQskYJ6wvmMBCc2AnCxY85-w1UfxafnxDdFZoMLRG-qxQAvXT3DOWSAq-YZbm3-C2NMbRHGe8EuNWxTnDT1aoALdE35RCb_Ux5sFNVlwhgFxewOSTOANaxmQRWLeIBX5hBKLBfrMG2R-b1CsekJV88gbardgOQtENJ_QurdAjRhvUFvKE7papd4gD3-DqOQThgzzDSVZMCyYkjdvkJB4Q88W7GDAUmPRG2Rcb1B4eIPo7xNuCH-DQukTjpYq3lCLBZLcb5DZvsB9cVpgsnWnReA32IxbVOMNohpvsBm3vvwNoilv6NuCswyIuVgwuwXHG5C0JP6G8BmQQ7dAbQtvUHn2CSU4C9KyQFLhCVUE9w3ls0BU8gktJAvisaAlA7qaR95gc-p5LBANfcKQFHzCdNWC7C2QFHzDrgasGC1QC88bRv4n_MWLkwX6xBtUVnqD0tgbTF78iR494RfW7IcFNi9u0YJVDfA5WqBS2BvmMuC36nmyAAczQA_9BC0SGqBW0Tcoub5hOwNSNEFS4QnZNwuqs0AE9wnFFQvUKPwGLTc8ofZhwXQGaBnQgO4sWNGALkL_huIsUEvLG0404BfWTJIzwO4bsTm18xYo4L1BGyqe8AtrVpPxEzbpxIBiQjdB2zyeoJl4gqKsBSoNvWF8BiiEGxCTBXlYMEywObUK7E9QGDYgTQuWM-CX_g01g74hRQt0429QKegJNi9OaxiQ1YL8BtHQN_zCmj8LhrNAyytPqCplv0GE_gntp1j9Al3gDYR_AyRvntA1nG8gPBiwmgG_dD2PYIGa9Z8wdWtvULvTE5YWQd4g4fQGmzVDOf8Jx_9hNdnmxXbX85_w4v9dNVkbf57gVTV-Q9wGBGWUN9i8uJigotMb7IqwSo5v0CapN2wL1ABngGjZG2xeXKMBv_R-2DsJ07HgWFDVcf8Gtf-8QUXFN7RhgcqzT2hy0zeoLeUNJDkDxJ6e8Es1-dsW_BFr9gZMNWS_QTLjDXY12ZmgFrw3yBGf8MtuQMmqN6xjwJGMfEPsFmhIXgA5jhbUYkHvFoxpgUqsT4DhWmAzbm3OeoMao5_g1Sj8htEN-K3bOhrwZ5y6WdC9BSsb8AvjjsOAXxh3TRZcyv6CkroFzVnQowWrGFC1ze0NJVpwnAEtbgu2BV2E_g1uWaAC-xu0ZeINKr-_webyaqp_wy9M31ugTbtPmNqW-wZtvXyDNnU-YaVggS7wN-wkPv5Ll_f_rAL-B30j3ykG_KID0rFAlbIn_NIZoiLqG1qzYAQD_kgHdBPOMiCGboG2qb7BVgl7GJBU9n-DJOgTssznDWrWf8IvTD93A6pbFvhjQW0W2J0hflug7ZNvUFf1G9a2QF76hF6XAUO39gabrfdtwPyaBSaXXyp0v-Guyz3hRAN-qWJrxN4g6fuGOQz4hY83_wanYo0BqVmgbVBvmCacbYDzzQK7xn2KAV5ltDeYi6pBhbI3lGaBXQG3GbfKpG_43zFuEtobcigW2DVum4-PbYG6XZ9QtM3tDWNZsJ0BVe7yhOZMMDtDOrzCgJwtuM0jT5CAecLQxts3aHvsG6wNeE41wDf80jdSigG_1LhjseAeHPIElQne8F_18X-DAvw_Ifxp9VzHXbzhTxi3WVv_I8ZtB0-bj_dtgFeZ9A02474H-b0giBC8Qbr0Cb-w5j-qnps7NnXMxhvitEA3_gZt-3pC1jbGN2gp_g3aWvsEHdhkgN3l_UtHyrTgl6r9tEDC-A3a9PeEJlX9BjUHPaHrI2_QVLxBa2tvsPtV7Lq8ighvsKv2dl3eZvo9WSBy_ISVswWjWvCLDhgW_KIDsgGneAvUvvcGDckLzMIDoIPP3iD6-4RfuHyLFujW3rAt8LFboPLdG9Rc8IYrJF4QSrZA0ugNtkrwnwV2Tf8PNETy0QISuAEazidkTcUTfjvJJFugYt4bROmeUHXUzRvUoPyEX3ZsqhnqDXafzBwW7GNA1-GxbzCr9iMEC3Tjb7BVQl8WaBHkCb9piGGBvZ9TCwpP-E1_HAv00H_D_oLvg5BR6qpn5a7CSMiQeCRyrL4GV93aKa2FWZIdRozufC31nUPy9zf-_nDnA6m3cDdRfz_Xa3O6nX317u_PHYx4bB9Gvh_xbhGG9dPU618f8evwm36V9fMdvvOpFv1arbX9ZXhXiXXPvIo73vuaax1L_UvHhdFauB-OucZZo6tzhjMbNLGmsfdqvrnmT9QvxDKjdzPlEwuX6X6udXYPZ_MpWMmJm_spya1aIJJauzp91O48dzewzxGTS8jknh2PXmYYaeQcuaDrneGL8evdo9DPCvzt7BKxn9G_ukYqddaQS7nDFNNuYx2sZ8TjR4tqHmYQ2in73MOCzqdbDvhq2jXvEmCv2ets7EW2whladGmf3Hpizr52j2WNaMEz1qy9Vm5l1NJPJ1Bs1V7vmG1sY40cV0uFr_Eln8JtncR8Th9236SVIXbQU92rJi5cC-o-hhiXvvw73ClxDTupO8XCSH-79tza4SnSDNv3lddw2NfhTz6NEXoYZwY_-cpeNyM-J9-_9uGev7DqiGX0sA6WxNfV7TajQ7aXgUysqHme7-TEFLikvUC-LN8LY9jrGeVgq9-1yYWV94yVlN6av1W6GgJz7_jE6sFxPaX60-vH6K8V8qotjW9MhnjPOhPkp8U5uEjcLrm9_TiLe55r96LpwvyP8xjYtyHJjAPWVIfj_yPgAOnk-C3GZLW5ZuPJMAbGNnw1HX-r2czMt7w7TO_AfvvYpWz5XziRUUCK9JxP40vVU ...
#            'end_of_fade_in': 0.14499,
#            'key': 3,
#            'key_confidence': 0.326,
#            'loudness': -3.704,
#            'mode': 1,
#            'mode_confidence': 0.39,
#            'num_samples': 4083660,
#            'offset_seconds': 0,
#            'rhythm_version': 1.0,
#            'rhythmstring': 'eJxlW9l17DoOTEUhiOACMv_EBrVQ7fvmw8d2tySSWAsFqLU35tPj2c88-cz2rPXs_bR3P-c8Ld5nryfe_H3Sn92f1uI501-c5-CO7p_1jPPM4F_tbXXteE58D-Atb316uNCqj6YvfLX2ms8IPncN3jZ8S11z3lq0rhm1jfk0_LTEp1gFz1kNG8OGaottvDiTdxDv0s1R5x3afN3ceu0aK7X97NpNH0-GHouL6s9okAKeMmozdeyGzU6dZfZn1HW12qxP8AMp4O6GB-C6OZ4VODz_77oPV-DP-qjX819ILdYrUdUXs1Ty-mFTdzb-Ow_2wL--0g9HlZU2HhLJlzVdu8CVcXiKps23f_Y6fJcW3G-oy6CgleZz49aYHldltaPCe-WR9AbfrlNpf87grNMq5ra4HJUTXykzKi-txJf8yzKPYEPC20uQ8vA2RJWg-1M2kR9OCdJbdZBHv8WpBTez7OEan_eT75JLJNfwFq4R7y6sQsKCnsf2gTZ9eSU3TgkP6hInmk_ltqPM0V5iT8oDmOqyxJLqCspFqtaX5yuL-SB8HgtXkVdwXKUvgsJLadQlwaA1Ek3vcozu4NTjO5kOxiQ1Dg15h17JiRA_os1PCgW1Pee2Vlh3sTAuBmxm6236lH5v5_mI1IwSCYDL0HWqA4bOEiyBZ9t76opO8ii3tlVssHbM_vTWLTZKZ0qfMHwlDCv75ikQYUB-2XGeDvl7KYQ7uibuWZf886h7nnkqLZcmj0lxdUxbd6CHjs8kjx5V9ryv-lBGmnv_K5yZjYlSWHOP56VgBpex2hE2kwVT5XERCrGgj58ZgkweRtM404vkZjDa-lFe2T1SBBwFUcZ7J0HaFPTDrjHv6OucOxbEh2_3JoFZc7QoFKaT8B4vf_PzHqW3xWO4mB-dgaFMXUwNMQjCDiZMv5cv6qfA-61-ExSlvHtQ_4gQld2i4lRNSmVg_i8-KOmNdBPu10VPNvfa_dZFTNUISdsGdtvoSifsiic4AAm8aRgnSKN140Tzh8AYg0PPSoeo5tdmzpNCu2P5KeUc3wdoZm0q_CDJwlr6oqagHRmGIc7Nr0HMZLLYCTkUZenruC6TqGbDJ2mTIgoaj9I172l15FoR6leUwXXbdavtbsOODXfytKN6Rgn9RCidBziC2Gk_vwlaMu7USYig8A9vIn02skOZuKrkYqNsGGXzmVYCMyCABmz4McRXwsJE65JLMsY3SZtDHN85NZKAEviQ4HF2oZ-vqFFoKhbLlsIHHYM-w7BIkbh4UPqN0LRRDaRtIBLLnRgkJcG0_31nDzn-UFhwukTLLHRCJNjwJAMHIGPtKfotA0vltMAKP_fz17unYB3A1-gdendreG_G_sAVbEoqRcGEXjcEHjlnPvxhxCDYA42FlCE_4RTYxP8XBuVoFGKCp8-UjWvuiLZVwSzf9pb_SRJkSy3H_axi2hDJ6-EC5yHr1Rbs1BKE9olkpZP8xwNrloVks53fEFBgYVQwcUAcdjaqKUHZIgr0gYhNqw6WHkkm5YShYAS8SctPbFoPAUJhExXC0vUYsU1Kq_UW4kDkSffnykUvWw6PMD_G3rsmXMbGeXFcSyR6dyzJGwvii2zWOJe3VDoaMKGb8SXZMZw53ALUyLjwDu3RRMQ3cDsuuI7hGqYYcKhkrl_x1S93I0k0xBoWL0udFGNo1klIQXiCyxWH4mg6UuP9C9SU7VVxxPRDvHyw4ZVapkCyHXALWykZt3VQSdCNFdhynMVryGIOetuWY3GTfKvrmI_v4Mn4SCr0uH29k6kyu9WWUIso6wjImGgqFMBpnGMgx33YIYr5CYU1IKqXgYRguQ4fV0rQq0wQgUZPrfZF1SKSdOy4w2bD5sFCMgWpXR4oy7HhdUQuo847AlUegNYkoAmu_rCT7zYCDYoPkgHinE8Kr5WDXCO1VSuX5sAUdJ5gtacTnBukkdl2dGG8HVxqEmJMEwVJ4cNUyDEi4z-jCNumvbWLDESs6YWI7LOUZsXjRFmijV3xu-TJRTCEk_KdnbKAuCTqZtFE9dGXGCu2HQGKzYKE4IZb6qq4qlIVQkDb6shZss-9vjymzemUnIU-B_I7uYlgdj62m5AZZLwc2gAH4WHelrKM3Vwf4gmUl0F7iwEMIO43CQ2UBr8y8HkHTOD6ly2scpRGnvSImFCRh0-IjmuiSRazLk5KYIYo60l7C64Lx_uXZpkLHdF28GAJwSq6YNObgswz9BINSsH4I1MIcQyGRbkJff_lQJYztVI_UK7U4WwG2gKNpwC6qi-GvNyl0-Spdry6uVUuoyAGIsbitpCfsh0R4HAWPahUVQFgM9yIz7DTMWZIBoMdoP58NZpwLP7AXoPO8uhrpYwqXYB1IhWdU9iDWJOM0zW7A7gTnoezOMo-ZYdsgESeIqMf9JCmZ-pNOemhlayqO1U5KUlFIhXB1w7aPUOghuGclcOinMAZ4NmMQwxkPO_NjaVAWZwqAh3gTQR8wPL3_SrJOIIVwR11PHiyH-MAlkQX_xS2dhrEV8O-TOyML5FFleUlw77_FFiQMMNdRYL6GYCFrYr0mVAhFDUoTqw5lZUCJZmphK8kIKtFDjugQVK6p_MfAF12JajKgbyajrtq9CQgflb9CZfTQgzPhwrz4WznXIWLJ3HE7dAnHJgRsWq3x_CoSsdkpusEl2lHhA9wxRLI2F7dgvaBOgJAtyL0U7uFEwTqs32RV36Q8IZesV3W8aCnUeymoWB_QiepSbwvYKMT0UYzmmhDwSzBLEBl7SvGsPNu1pSGXyX31zZjBgnooIrseEisgS1LUR7wlY8TEyvVi3UzYVfTDJBALRj43xVWYUg0BywJU6yotk2pJcbOzC168QkK2kNxXzqZj95EOXSmC4XbS30IWqMkQoghNXuoMJcQ1_RaqpiAW4kRW3kdlbzZhx2lZ0mgP64T1ATWUApN8KcTBfNZIpM0mXNTHn2z7lV-qrP7LH_wp0OJ1NG-EDn_vBdX1p1Zzrf49uYklb_TXYPAg84zKNhUdfTqi_SH3ITQeykLNBQpB4VS8Hk304Z-VmHK1a8LzJheGc5PqSVOpWmiYtgO-ClWqzehyXOKSsa4EC2R_eMkf4ElmQJEOJ0MI1UnIkiaje6rU3PIyJPZF8qAsfwmbn_6pdxFqiFFi_RAbTkssQtAqdlsoTUCfjEiSoSAHYrxfHgvvTKYh1l1S6qZHpaBwuN519sN2j-Nhl-iOiBoa5lQGMU3CYKWDhesVSP6ItxiX9ncpTGTmpkETGNh22WML6a7dQ2xJT-cJob04wikqApqZx6MKXA_fwiUv6YFQqo2jku6Q3MVBt1IVa636fiqShah4BEOAipDNOLUfmXMXiHtZjYfrbqiM2z0kFiBbAlVaSjC7HmEmsnaqzgNwc5GiNqe1rt0MYSEhGDaS3qFG0o-acDYAu5Q2-GSUU2tjifvK9VndoBkyeWy6MereyO3csCllnBbSGJJtmDZXAc0SZAEGHLJpVOxO-_ZRVK0HbRH3Kz7g1rpJy5DsaRWvfnAQ1_YkrDatGzFisSxgttnEXCKIl1CpKspSL8txhQKkgDSRdwyW2V5yb2gp5MOhmohuHLhkh9R9lJymsjiBMUxzpfY11KcTB7PsHbCl-Bog6EAcYSqdVdHfPQQ9hPg8JN50NT5ItW1Gx6kq-Uga4j2WIPNWOc_inQk0aKONZrJclOJ4nWwptH7Y7VLTbYjk ...
#            'sample_md5': '',
#            'start_of_fade_out': 181.09243,
#            'synch_version': 1.0,
#            'synchstring': 'eJxdWgmSIzEI-0o_oQGf___YGkm4M1uTnc10fGAOIXDc3_4-8Zi18YTt-aynP_Npz3j8sY0XBkT-P87H583Ap25n2HziPb_cz_v9jPWYnwX6Os_OmPPkPG_nib_5-Dw9q_jK5XKl827kjOn529rjZ_Wen_bzQaQIlq8U8MGAnb-4f5yfiVWx54B0nQs6pnPmy11TVjd90s-_rdkpacd70zTH4IFnIUEWDhL4TaEocWDbDY3lKgtH3mdGrgAJBiYapR2p0okfbBj8laM2pYWsDVs3qIsWyM9TXArXob8FRUwdCWrIPx0fL20SGNSxZMNPjoFA-0dJeNfxyeZi53TQeFDIXidyHDawERcO_VBBOFTXEUIDtECN6lDvhDnS3azpEJuHblRLe2jaRokozZAZFoySXoM_0gHOzJX-ueEK1Ea7egiJOq8PUOm07MSzfpVPsy0cZ9wR1M7AGk0zrrfBwWvl1CDPL2M3mcBMPtRrQuSHGGM0TIOKqU65z4vTW-qnO8SSY_i1acN5aMv3nhfDTvzFyvjE2M494D6IzvMAguzNjaKs7RpsCJ44kp8RS6ajdIgaT52sl_tOzd9YM3UVDBdjFFQkOF3VViKLJQh04cM5hyd8GP3D6BkI5QmFdwJUBcR4bzjC9V-F1mxYZWF4h35tlopTsbMDfAzaC5wiBXp2ows27BDw5rFl7wOUDxDLR9phpq-1t0GHcL98LejsBYLifR6Or10jqfZZT6bAT4v8rvb7mjWx15P-8_y_wX_HDMSLUfV56FTIAurAB8-ogA8t2P2F9gQVPVGefxiSAPHBcbiRHwayQTzQigU83FbucFYZEybqjY8ijTTy-fnj6G6tghyoYMJWi_OXNmwnuj0fdkRTrnEcumEr5ymJs3B5-VNJ2_t3RoNt00VOODnSFuL37HXE2SNfJxUNLNiafLdFquMEn03JOuGTWnNozfSLWSqPT1ZteiRh9Ld0roRFxN-u8DmLN5ijIwI6F3dJaDw8FNj48Dipafdvr_gAvP0YV0vJeesJ0-ssm14Tc7rV7qOOQDS6enhpg5pSe_mqvVq9bxLs7nXMN3_mla1aOVqrc-cwqC2DEONBLtJfSUxi11bjuetZ-mMDEUlfbkJhZGqT-rnsHKQW6T1nVssjnc39pe-f7T2zPH3aZ2mC5qKO8XyuArqJXa_poMsjzSUOdm1F2PdcJIEGlgmE3oaMOMjwCtSjtaHh5t8mh3Pd6DEviIgSoUu1V3av87b44wfnzTDNlWORg-EQnSjXpDYj9JqQKnapvVUEKpE7zB2uENDv37j4lQLMUH9yn_E3ylq9-qfc76yFAz5_hG2lBiiXlkv3ue_9BxnusvN_r9b649uu3cWvPOkqs5AgnKacVucHsmZqmom2zT4Rm2knzEgSFYmq9KWrsCmFnYcOCA-8TgY9z97o_aBkuHgSkqaTDjiIVa_3ZNGrnmz-AXM50qo_EANPwHORrkOcMB7_6MdM3_U8D1kHh7iT0oCudHjBJDkicymm3cXnXRwLghhotC1xatEdWxzBvZ1EKEg5CfQkhqRoLj6KPVWIYEzXPhY6w0cPad8tAYvb2iKbeslvjZz2ZO7j62FVeozSrZMph_ZWVYF1neeKYtfWxKVCeijZiuLPOjvJqy-CnkuMqH1SF8xZs3Z3p1R9ZHLbwpB0nA45qE1ouudJ4CFQ2v7y4_HwbdQ5UPdsRGd2cvXJFQIUnF76pq07CXvHiDdlIPNu2IrlQJZkgaOQ1NkrQDxvqooi7xggafm0j0o6b34mYiiGyKnRVN9ZEpcjcHvhZi2KgoLkl0Qgfo5wRYg5Ky4mffqqo6jg2VBmOKWAEhRmMUiFszRGQVPlJ-jEfm5ysFvo-Qt3tSLIje6bumdapiSpJoAV1ewwGrab6eoHN9bm865SJFjAD9SBQewFt3YWCqP2fFlqMmhzH6PRVk4_hwviwuQgBsdCYnrrBaOmpx6hhsLYUmEddSoU4pKcVsrDdFk-iY48Nm0W_dalcMT1FPEgcQJsCx6OVTsc64Ckz-fyY2Ytnh6lpVOTAQ5JWdIjKx1iQwiP-cB1x54TcaU84JAYgNXglVNTG3sMIvfvU15ykiOAmZ4H7nbeI5u3NFHSvDffACWaoGJgJRxKFSTQoaeZR8YBeRIhluX1qEIsKkO8KPAcIDLFwXIv0JUM8XnRzwr29IBZjHUv-itslzS6Tsj3TZ96FaFOTQguWbmV0avBED-FtBNiDeHnwuC4Z9iCzkm0E9QVLrY7l2tTRxKjCufrjlWHE57JKUKF5C2WBQyE9q4duLJzYP_qWzy7CWQ8UVl0_vRDOLlSWjWLwG7a_VgJrYThpjbUeeA0VljtqRaL0q9Bt-tLDtZv-Y9l-xUE8XH7NI2Y97NQ3PN-if2boJ_5kxGJF-Nb88e2Xc_bNcyXZedt3bkaL8Lirh29LMuTtPSJ-nF627zK85ftlG9C-xn8-z9Gq8Hj5QhG9bFL50q_Q_J9Ntw_6zQWzuQ57mpRle3sIwyhrpP1e3Yh4_7RtTxLvvTqk162o9Ovu2CtZOuqXs7syBvw-FY9nV0D-F_7MUtpGuA4SKdikAwiGh01NdJTdc34d0-D7ESxBk8mcdgJLg0VnTG7dw1syL9I56LlbGGFKjEDi80OytOYsURCEkqNwLqlJDJuN9EfcB1nezCRuWoSd-YRD6Y38pylzpqzcPSoriPRJas3ku7i9ywcp9jJYr6xzWUsfubS-djFERAzu7r4tZWztqeaDequL0HUQKHKKvSI3tUNXsnoQNTBDZhY2sC_lt04dRQNfag2wNgRW5t-0Is-6gX6nlrh2ZMXxeU0iTPwbTa_6LHkjA2MpCtD4NESx9mZ_Dcy48JHhkrwJZobKIRt8m9Q5RDx2OgXveQIYCkmczOZzlzBL7fEdYNaz_Z1oUHBG7pPk5wavN-r67-fLyePzHtbQe1w21CvuOUpmquTHOjl002SAuNgbXCNbBU9qMhmcTnopD_Uv2CYDerJTmqkFpzW3-pIKPHvQZJFh9-iGutmPc6mDnKuHMPR0lhswoItTfGWUUcncatiBfK8WIWNDRsMwVGuvPlrY9q6ZKbU7i-cK6wW5YGbienadzEwK5WDeXbiDFurCMZQt7qRtTLQQe121QHo9KDcWc9QGx2sA5Ea-mMLqSm9ketZXQhMgQJ6KXSZJd7wyngi5mLE_vDSymGTJtWwZ7rhAJXQzKVglmlkzuU6daSRcchydwtkfsBjkp-9Mt_6c3InS2YV8xJJyHiBlcBYEAn_bhWOJUC50Qoc9DNnUglW2iyZuOm7jjR7LfcghLMPjV-NBW8GRjfiDJqUOd8EvIiNzBp2jNHWU43SQOIamxcaSs3UUhMxROV-3B9I9syZBeWkS6PBEuTXQAdeE4Cx5nLsNMmDHXGPHoHDVTooQr-dIqXPgTqiuu4D0h4RUQLauGXOQDXL2jcVasw5gCj0jQASZ8eOnlHgPe9DCQlQCCIiuTa7qkizuphs6KDgIB2VG4r2M-OIMhug2EneWR_mqg2J0tgtCWTZQfrZITVSCUvcqKtHpld50BZtQFnnCnbAX6OLtJdtU2Z31LFuYvtDbM7QU3IRawgIrwhRJeQJ0gjk5OhsPgSaQmasTR0FEf2C0WBKm68qcKZLLlVteiNiq3PB6BpMDOzZbfVMicgsuoz5CFxAwbAqKAnQ3NbuhW7_ug8taFHwn1hkNj7qVhKFcgrZVIKmV8PrG_MAVQAKkThOiv2iomVbvyPgAbJvv-nQMT54Yphtkd-kl2z0EpnrQdpyC90nq4Ey614EteJdcug8R6A1lFhm3qV0tS6KOzkCojFXsgAeuDzkUltqQhJzpDwikCkpNXSSphpDPm5Lx1TeW13aqVjPmxveFvD2nuBHAiLee-z3Vuc85Bx-m7VV2Wl5NEXgNHC_4O5O_Gu8aUJVnvCE2JlYYRLz4LYdUAWFsQGD7yUox9RXDaIVnr1sw ...
#            'tempo': 199.669,
#            'tempo_confidence': 0.284,
#            'time_signature': 4,
#            'time_signature_confidence': 1.0,
#            'window_seconds': 0}}

# %%
# Put section anylysis into a DF
song_sections = pd.DataFrame(song_analysis['sections'])
song_sections.head()
# Out:
#    confidence  duration  key  key_confidence  loudness  mode  mode_confidence  \
# 0       1.000   7.80605    8           0.022    -7.945     1            0.343
# 1       1.000  21.61488    8           0.644    -4.865     1            0.583
# 2       0.827  30.61230    3           0.312    -3.029     1            0.390
# 3       0.814  17.08800    3           0.663    -4.462     1            0.546
# 4       0.458  21.61765    3           0.299    -3.236     1            0.352
#
#       start    tempo  tempo_confidence  time_signature  \
# 0   0.00000  199.867             0.478               4
# 1   7.80605  199.015             0.375               4
# 2  29.42093  199.834             0.251               4
# 3  60.03323  199.676             0.308               4
# 4  77.12123  199.302             0.245               4
#
#    time_signature_confidence
# 0                        1.0
# 1                        1.0
# 2                        1.0
# 3                        1.0
# 4                        1.0

# %%
# Make DFs for the rythym/meter data
song_beats = pd.DataFrame(song_analysis['beats'])
song_bars = pd.DataFrame(song_analysis['bars'])
song_tatums = pd.DataFrame(song_analysis['tatums'])

# %%
# Remove data with zero confidence
# song_confident = song_sections[song_sections['key_confidence'] != 0]

# %%
# Define new column to get the actual key names
song_sections['key name'] = [key_names[key] for key in song_sections['key']]
song_sections.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-297e005cf18a> in <module>()
#       1 # Define new column to get the actual key names
# ----> 2 song_sections['key name'] = [key_names[key] for key in song_sections['key']]
#       3 song_sections.head()
#
# <ipython-input-13-297e005cf18a> in <listcomp>(.0)
#       1 # Define new column to get the actual key names
# ----> 2 song_sections['key name'] = [key_names[key] for key in song_sections['key']]
#       3 song_sections.head()
#
# NameError: name 'key_names' is not defined

# %%
# Visualze the song key changes in a scatter plot
song_plot = plt.bar(x=song_sections['start'], height=song_sections['key'], width=song_sections['duration'])

# %%
# Segment analysis gets even more detailed. This is like a note by note analysis
song_segments = pd.DataFrame(song_analysis['segments'])
song_segments.head()
# Out:
#    confidence  duration  loudness_end  loudness_max  loudness_max_time  \
# 0       0.000   0.14499           NaN       -60.000            0.00000
# 1       0.701   0.37846           NaN       -53.086            0.09923
# 2       1.000   0.19034           NaN        -5.641            0.07419
# 3       0.395   0.32490           NaN        -3.637            0.19292
# 4       0.210   0.09315           NaN        -5.293            0.02138
#
#    loudness_start                                            pitches    start  \
# 0         -60.000  [1.0, 0.742, 0.136, 0.115, 0.243, 0.261, 0.428...  0.00000
# 1         -60.000  [0.685, 0.651, 0.633, 0.555, 0.601, 0.788, 1.0...  0.14499
# 2         -57.899  [1.0, 0.483, 0.413, 0.375, 0.324, 0.275, 0.223...  0.52345
# 3         -11.995  [1.0, 0.102, 0.076, 0.12, 0.057, 0.027, 0.027,...  0.71379
# 4          -9.876  [1.0, 0.754, 0.098, 0.205, 0.059, 0.021, 0.118...  1.03868
#
#                                               timbre
# 0  [0.08, 169.697, 10.519, -30.426, 58.116, -50.9...
# 1  [5.138, 112.647, -4.112, -11.762, 41.045, -40....
# 2  [34.586, 4.084, 105.627, -248.879, 13.544, 207...
# 3  [51.129, -6.478, 62.62, -53.568, -59.416, -9.3...
# 4  [51.771, 10.204, 74.662, 45.57, -33.843, -30.5...

# %%
# Get which note spotify thinks is occurring at each segment. I'm assuming that's the pitch vector with the max value in the list
song_segments['max pitch'] = [pitch_list.index(max(pitch_list)) for pitch_list in song_segments['pitches']]
song_segments.head()
# Out:
#    confidence  duration  loudness_end  loudness_max  loudness_max_time  \
# 0       0.000   0.14499           NaN       -60.000            0.00000
# 1       0.701   0.37846           NaN       -53.086            0.09923
# 2       1.000   0.19034           NaN        -5.641            0.07419
# 3       0.395   0.32490           NaN        -3.637            0.19292
# 4       0.210   0.09315           NaN        -5.293            0.02138
#
#    loudness_start                                            pitches    start  \
# 0         -60.000  [1.0, 0.742, 0.136, 0.115, 0.243, 0.261, 0.428...  0.00000
# 1         -60.000  [0.685, 0.651, 0.633, 0.555, 0.601, 0.788, 1.0...  0.14499
# 2         -57.899  [1.0, 0.483, 0.413, 0.375, 0.324, 0.275, 0.223...  0.52345
# 3         -11.995  [1.0, 0.102, 0.076, 0.12, 0.057, 0.027, 0.027,...  0.71379
# 4          -9.876  [1.0, 0.754, 0.098, 0.205, 0.059, 0.021, 0.118...  1.03868
#
#                                               timbre  max pitch
# 0  [0.08, 169.697, 10.519, -30.426, 58.116, -50.9...          0
# 1  [5.138, 112.647, -4.112, -11.762, 41.045, -40....          6
# 2  [34.586, 4.084, 105.627, -248.879, 13.544, 207...          0
# 3  [51.129, -6.478, 62.62, -53.568, -59.416, -9.3...          0
# 4  [51.771, 10.204, 74.662, 45.57, -33.843, -30.5...          0

# %%
# Add column to shift the timbres back by one
song_segments['timbre shifted'] = song_segments['timbre'].shift(1)

# %%
from scipy.spatial import distance

# %%
# Iterate over the rows in the DF and calculate the euclidian distance between each timbre vector
for index, row in song_segments.iterrows():
    # Skip first row
    if index == 0:
        pass
    else:
        eu_dist = distance.euclidean(row['timbre'], row['timbre shifted'])
        song_segments.loc[index, 'euclidian timbre'] = eu_dist
    
song_segments.head()

#print(min(song_segments['start']))
# Out:
#    confidence  duration  loudness_end  loudness_max  loudness_max_time  \
# 0       0.000   0.14499           NaN       -60.000            0.00000
# 1       0.701   0.37846           NaN       -53.086            0.09923
# 2       1.000   0.19034           NaN        -5.641            0.07419
# 3       0.395   0.32490           NaN        -3.637            0.19292
# 4       0.210   0.09315           NaN        -5.293            0.02138
#
#    loudness_start                                            pitches    start  \
# 0         -60.000  [1.0, 0.742, 0.136, 0.115, 0.243, 0.261, 0.428...  0.00000
# 1         -60.000  [0.685, 0.651, 0.633, 0.555, 0.601, 0.788, 1.0...  0.14499
# 2         -57.899  [1.0, 0.483, 0.413, 0.375, 0.324, 0.275, 0.223...  0.52345
# 3         -11.995  [1.0, 0.102, 0.076, 0.12, 0.057, 0.027, 0.027,...  0.71379
# 4          -9.876  [1.0, 0.754, 0.098, 0.205, 0.059, 0.021, 0.118...  1.03868
#
#                                               timbre  max pitch  \
# 0  [0.08, 169.697, 10.519, -30.426, 58.116, -50.9...          0
# 1  [5.138, 112.647, -4.112, -11.762, 41.045, -40....          6
# 2  [34.586, 4.084, 105.627, -248.879, 13.544, 207...          0
# 3  [51.129, -6.478, 62.62, -53.568, -59.416, -9.3...          0
# 4  [51.771, 10.204, 74.662, 45.57, -33.843, -30.5...          0
#
#                                       timbre shifted  euclidian timbre
# 0                                                NaN               NaN
# 1  [0.08, 169.697, 10.519, -30.426, 58.116, -50.9...         76.382259
# 2  [5.138, 112.647, -4.112, -11.762, 41.045, -40....        404.424989
# 3  [34.586, 4.084, 105.627, -248.879, 13.544, 207...        338.376284
# 4  [51.129, -6.478, 62.62, -53.568, -59.416, -9.3...        115.409482

# %%
# Need to scale data later
song_segments['scaled timbre'] = preprocessing.scale(song_segments['euclidian timbre'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-bb567f766928> in <module>()
#       1 # Need to scale data later
# ----> 2 song_segments['scaled timbre'] = preprocessing.scale(song_segments['euclidian timbre'])
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/sklearn/preprocessing/data.py in scale(X, axis, with_mean, with_std, copy)
#     143     X = check_array(X, accept_sparse='csc', copy=copy, ensure_2d=False,
#     144                     warn_on_dtype=True, estimator='the scale function',
# --> 145                     dtype=FLOAT_DTYPES, force_all_finite='allow-nan')
#     146     if sparse.issparse(X):
#     147         if with_mean:
#
# ~/anaconda3/envs/python36/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     594
#     595     if (warn_on_dtype and dtypes_orig is not None and
# --> 596             {array.dtype} != set(dtypes_orig)):
#     597         # if there was at the beginning some other types than the final one
#     598         # (for instance in a DataFrame that can contain several dtypes) then
#
# TypeError: iteration over a 0-d array

# %%
end_segment = None
plot_kwargs = {'s':song_segments['duration']*200,
               'marker':(4,0,90),
               'edgecolor':'k',
               'linewidth':1,
               'c':song_segments.loc[0:num_notes,'loudness_max'],
               'cmap':'Blues',
               'alpha':0.75,}

# %%
fig = plt.figure(dpi=200)
plt.scatter(x=song_segments.loc[0:end_segment,'start'], y=song_segments.loc[0:end_segment,'max pitch'], **plot_kwargs)
plt.colorbar(label='Max Loudness')
plt.xlabel('Time (s)')
plt.ylabel('Pitch')
plt.title(f'Pitch Segments for {song_test.title()}\n by {", ".join(artist_names).title()}')

# Print Vertical lines where the song sectioons start
plt.vlines(x=song_sections['start'], ymin=0, ymax=11, linewidth=0.5, alpha=0.5)

# Save Figure
plt.savefig(f'Images/Segment_Analysis/Pitch Segments for {song_test.replace(".", "").title()}')

# %%
plt.figure(dpi=200)
plt.scatter(x=song_segments.loc[0:end_segment,'start'], y=song_segments.loc[0:end_segment,'euclidian timbre'], 
            **plot_kwargs)
plt.colorbar(label='Max Loudness')
plt.xlabel('Time (s)')
plt.ylabel('Change in Timbre from Previous Segment')
plt.title(f'Changes in Timbre for {song_test.title()}\n by {", ".join(artist_names).title()}')

# Print Vertical lines where the song sections start
plt.vlines(x=song_sections['start'], ymin=0, ymax=400, linewidth=0.5, alpha=0.5)

# Save figure
plt.savefig(f'Images/Segment_Analysis/Changes in Timbre for {song_test.replace(".", "").title()}')

# %%
plot_kwargs = {'width':song_segments['duration'],
               'color':'navy',
               'alpha':0.75}

plt.figure(dpi=200)
plt.bar(x=song_segments.loc[0:num_notes,'start'], height=song_segments.loc[0:num_notes,'euclidian timbre'], **plot_kwargs)
# Out:
# <BarContainer object of 1006 artists>
